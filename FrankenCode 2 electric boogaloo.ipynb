# %%
# Import packages and read-in files

import numpy as np
import pandas as pd
import xpress as xp
from datetime import datetime, timedelta
import os
import math 

# Read in files using the explicitly defined base path
ch_0_conversion_rates = pd.read_csv('channel_0_conversion_rates.csv')
ch_0_schedule = pd.read_csv('channel_0_schedule.csv')
ch_1_conversion_rates = pd.read_csv('channel_1_conversion_rates.csv')
ch_1_schedule = pd.read_csv('channel_1_schedule.csv')
ch_2_conversion_rates = pd.read_csv('channel_2_conversion_rates.csv')
ch_2_schedule = pd.read_csv('channel_2_schedule.csv')
ch_A_schedule = pd.read_csv('channel_A_schedule.csv')
movies_df = pd.read_csv('movie_database.csv')

# %%
# To use right xpress and get rid of unnecessary error codes
xp.init('C:/xpressmp/bin/xpauth.xpr')
pd.options.mode.copy_on_write = True

# %%
# FORMATING
# Convert 'Date-Time' columns to datetime format
date_cols = ['Date']

for df in [ch_0_conversion_rates, ch_0_schedule, ch_1_conversion_rates, ch_1_schedule,
           ch_2_conversion_rates, ch_2_schedule, ch_A_schedule]:
    df['Date'] = pd.to_datetime(df['Unnamed: 0'])
    df.set_index('Date', inplace=True)
    df.drop('Unnamed: 0', axis=1, inplace = True)
   

# Convert 'Release Date' in movie_database to datetime
movies_df['release_date'] = pd.to_datetime(movies_df['release_date'])

# Fill missing values if necessary
movies_df.fillna(0, inplace=True)

# %%
# Slot duration 30 minutes
slot_duration = 30  # minutes
movies_df['slots_needed'] = (movies_df['runtime_with_ads'] / slot_duration).apply(lambda x: int(x)).astype(int)

# %%
from datetime import datetime, timedelta

num_days = 2

# Define the broadcasting start and end dates
broadcast_start_date = datetime.strptime("2024-10-01", "%Y-%m-%d")
broadcast_end_date = broadcast_start_date + timedelta(days=num_days)  # 7 days including start date

# Define daily broadcast start and end times
daily_broadcast_start_time = timedelta(hours=7, minutes=0)
daily_broadcast_end_time = timedelta(hours=23, minutes=30)

# Generate all time slots over the date range
time_slots = []
current_date = broadcast_start_date
while current_date <= broadcast_end_date:
    # Set the start and end times for the current day
    day_start = datetime.combine(current_date.date(), datetime.min.time()) + daily_broadcast_start_time
    day_end = datetime.combine(current_date.date(), datetime.min.time()) + daily_broadcast_end_time
    
    current_time = day_start
    while current_time <= day_end:
        time_slots.append(current_time)
        current_time += timedelta(minutes=slot_duration)
    
    # Move to the next day
    current_date += timedelta(days=1)

# Create mappings between time slots and indices
time_to_index = {t: idx for idx, t in enumerate(time_slots)}
index_to_time = {idx: t for idx, t in enumerate(time_slots)}

# %%
# Print the first few time slots
print("First 10 Time Slots:")
for ts in time_slots[:10]:
    print(ts.strftime('%Y-%m-%d %H:%M'))

# Print the last few time slots
print("\nLast 10 Time Slots:")
for ts in time_slots[-10:]:
    print(ts.strftime('%Y-%m-%d %H:%M'))
# Out:
# First 10 Time Slots:
# 2024-10-01 07:00
# 2024-10-01 07:30
# 2024-10-01 08:00
# 2024-10-01 08:30
# 2024-10-01 09:00
# 2024-10-01 09:30
# 2024-10-01 10:00
# 2024-10-01 10:30
# 2024-10-01 11:00
# 2024-10-01 11:30
#
# Last 10 Time Slots:
# 2024-10-03 19:00
# 2024-10-03 19:30
# 2024-10-03 20:00
# 2024-10-03 20:30
# 2024-10-03 21:00
# 2024-10-03 21:30
# 2024-10-03 22:00
# 2024-10-03 22:30
# 2024-10-03 23:00
# 2024-10-03 23:30

# %%
from datetime import time
# Set 'Date' as index
# ch_A_schedule.set_index('Date', inplace=True)

# Resample to 30-minute intervals (use mean of groups)
ch_A_schedule_30min = ch_A_schedule.resample('30T').mean().reset_index()

# Define start and end times for filtering
daily_start_time = time(7, 0)  # 7:00 AM
daily_end_time = time(23, 55)  # 11:55 PM

# Filter rows to include only time slots within the desired range 
ch_A_schedule_30min['time'] = ch_A_schedule_30min['Date'].dt.time
ch_A_schedule_30min = ch_A_schedule_30min[
    (ch_A_schedule_30min['time'] >= daily_start_time) &
    (ch_A_schedule_30min['time'] <= daily_end_time)
].drop(columns=['time'])

# Print the first 5 rows
print("First 5 rows of ch_A_schedule_30min:")
print(ch_A_schedule_30min.head(3))
# Out:
# First 5 rows of ch_A_schedule_30min:
#                  Date  children_baseline_view_count  \
# 0 2024-10-01 07:00:00                      0.019383
# 1 2024-10-01 07:30:00                      0.015485
# 2 2024-10-01 08:00:00                      0.009684
#
#    adults_baseline_view_count  retirees_baseline_view_count  prime_time_factor
# 0                    0.022296                      0.003611                1.0
# 1                    0.022928                      0.004694                1.0
# 2                    0.024245                      0.006021                1.0
# C:\Users\Elie\AppData\Local\Temp\ipykernel_1516\4019587516.py:6: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   ch_A_schedule_30min = ch_A_schedule.resample('30T').mean().reset_index()

# %%
# # Map baseline viewership to time slot indices
# baseline_viewership = {}
# for idx, row in ch_A_schedule_30min.iterrows():
#     time_slot_datetime = row['Date']
#     # Find the corresponding time slot index
#     time_slot_index = time_to_index.get(time_slot_datetime, None)
#     if time_slot_index is not None:
#         baseline_viewership[time_slot_index] = {
#             'children': row['children_baseline_view_count'],
#             'adults': row['adults_baseline_view_count'],
#             'retirees': row['retirees_baseline_view_count'],
#             'prime_time_factor': row.get('prime_time_factor', 1)
#         }

# # Print the first 5 rows
# print("Print timeslot_index 1 of dictionary baseline_viewership:")
# print(baseline_viewership[1])

# %%
# Check for duplicate movie titles
duplicate_titles = movies_df[movies_df.duplicated(subset=['title'], keep=False)]
if not duplicate_titles.empty:
    print("Duplicate movie titles found:")
    print(duplicate_titles['title'])
else:
    print("No duplicate movie titles found.")
# Out:
# Duplicate movie titles found:
# 4                 The Avengers
# 17                     Titanic
# 76               The Lion King
# 105       Beauty and the Beast
# 149        Alice in Wonderland
#                  ...
# 5748              Midnight Sun
# 5761                The Island
# 5773            The Shaggy Dog
# 5855    Fun with Dick and Jane
# 5879        The Perfect Weapon
# Name: title, Length: 258, dtype: object

# %%
# Small movies DF to practice with code

movies_small = movies_df.head(550)

# %%
def get_views(m, t_idx, movies, our_channel):
    # Baseline viewership at time slot t_idx
    baseline = {
        'children': our_channel.iloc[t_idx]['children_baseline_view_count'],
        'adults': our_channel.iloc[t_idx]['adults_baseline_view_count'],
        'retirees': our_channel.iloc[t_idx]['retirees_baseline_view_count']
    }
    
    # Scaled popularity of movie m
    popularity = {
        'children': movies.loc[m, 'children_scaled_popularity'],
        'adults': movies.loc[m, 'adults_scaled_popularity'],
        'retirees': movies.loc[m, 'retirees_scaled_popularity']
    }
    
    # Calculate expected viewership (assuming total population of 1,000,000)
    total_population = 1_000_000
    viewership = sum(
        baseline[demo] * popularity[demo] * total_population
        for demo in ['children', 'adults', 'retirees']
    )
    
    return viewership

# %%
def model(T, movies, our_channel):
    prob = xp.problem(name="Movie_Scheduling_Problem")
    
    # Constants
    slots_per_day = 34  # Number of slots per day (e.g., from 07:00 to 23:30)
    days = len(time_slots) // slots_per_day  # Number of days in the schedule
    M = len(time_slots)  # Big M for constraints
    T_end = len(time_slots) - 1  # Last time slot index

    
    # Decision Variables
    x = {(m, t): xp.var(vartype=xp.binary, name='x_{0}_{1}'.format(m, t)) 
         for m in movies.index for t in T}
    prob.addVariable(list(x.values()))
    
    y = {m: xp.var(vartype=xp.binary, name='y_{0}'.format(m)) for m in movies.index}
    prob.addVariable(list(y.values()))
 
    
    s = {m: xp.var(vartype=xp.integer, name='s_{0}'.format(m)) for m in movies.index}
    e = {m: xp.var(vartype=xp.integer, name='e_{0}'.format(m)) for m in movies.index}
    prob.addVariable(list(s.values()))
    prob.addVariable(list(e.values()))
    
    u = {(m, t): xp.var(vartype=xp.continuous, name='u_{0}_{1}'.format(m, t)) 
         for m in movies.index for t in T}
    prob.addVariable(list(u.values()))
    
    decision_vars = [x, y, s, e]

    # Constraints
    
    # 1. Movie Duration Constraint
    for m in movies.index:
        prob.addConstraint(
            xp.Sum(x[m, t] for t in T) == movies.loc[m, 'slots_needed'] * y[m]
        )
    
    # 2. Time Slot Occupancy Constraint
    for t in T:
        prob.addConstraint(
            xp.Sum(x[m, t] for m in movies.index) == 1
        )
    
    # 3. Start Time Constraints
    for m in movies.index:
        for t in T:
            prob.addConstraint(
                s[m] <= t * x[m, t] + (1 - x[m, t]) * M
            )
    
    # 4. End Time Constraints
    for m in movies.index:
        for t in T:
            prob.addConstraint(
                e[m] >= (t + 1) * x[m, t]
            )
    
    # 5. Movie Duration Relationship Constraint
    for m in movies.index:
        prob.addConstraint(
            e[m] - s[m] == movies.loc[m, 'slots_needed'] * y[m]
        )

    # 6 last movie ends at midnight
    prob.addConstraint(s[m] + movies.loc[m, 'slots_needed'] -1 <= T_end for m in movies.index)

    # 7. View Count Constraints
    for m in movies.index:
        for t_idx, t in enumerate(T):
            expected_viewership = get_views(m, t_idx, movies, our_channel)
            prob.addConstraint(
                u[m, t] == expected_viewership * x[m, t]
            )
    
    # 9. Objective Function
    prob.setObjective(
        xp.Sum(u[m, t] for m in movies.index for t in T),
        sense=xp.maximize
    )
    
    return prob, decision_vars

# %%
# Making schedule layout
def get_time(slot_index):
    return time_slots[slot_index].time()

used_movie_ids = []
def get_sched(prob, movies, decision_vars): 
    
    x = decision_vars[0]
    y = decision_vars[1]
    s = decision_vars[2]
    e = decision_vars[3]
    
    scheduled_movies = []
    used_movie_ids = []


    for m_idx, m_row in movies.iterrows():
        y_value = prob.getSolution(y[m_idx])
        if y_value > 0.5:  # Movie is scheduled
            used_movie_ids.append(m_idx)
            start_slot = int(prob.getSolution(s[m_idx]))
            end_slot = int(prob.getSolution(e[m_idx]))
    
            # Ensure the end slot is valid
            if end_slot < len(time_slots):
                # Get the corresponding day and times
                start_time = time_slots[start_slot]
                end_time = time_slots[end_slot]
                day = start_time.strftime('%Y-%m-%d')
                start_time_formatted = start_time.strftime('%H:%M')
                end_time_formatted = end_time.strftime('%H:%M')
    
                # Append the movie schedule
                scheduled_movies.append({
                    'Time Slot': start_slot,
                    'Day': day,
                    'Start Time': start_time_formatted,
                    'End Time': end_time_formatted,
                    'Movie Index': m_idx,
                    'Movie Title': m_row['title'], 
                    'movie_budget': m_row['budget']
                })
    # movies_list = scheduled_movies.to_series
    # Convert to a DataFrame for better organization
    schedule_df = pd.DataFrame(scheduled_movies)   #.from_dict(scheduled_movies)
    
    # Sort by day and time slot
    schedule_df.sort_values(by=['Day', 'Time Slot'], inplace=True)
    
    # Reset index for cleaner output
    schedule_df.reset_index(drop=True, inplace=True)

    # Print the schedule
    print("Scheduled Movies in Order:")
    print(schedule_df)

    return scheduled_movies, used_movie_ids, schedule_df

# %%
# Putting it all together

def movie_sched(number_days, movies, our_channel):
    used_movie_ids= []
    total_schedule = []
    scheduled_dates = {}  # Dictionary to track when movies were scheduled by movie_id
    thang = []
    full_sched = pd.DataFrame(columns = ['Time Slot','Day','Start Time','End Time','Movie Index','Movie Title', 'movie_budget'])
    for k in range(number_days):

        # Before each day's scheduling, check for movies that have passed the 7-day window
        eligible_movies = []
        for m, dates in scheduled_dates.items():
            # Check if the movie was scheduled more than 14 days ago
            last_scheduled_date = pd.to_datetime(dates[-1])  # Get the last scheduled date
            if (pd.to_datetime('today') - last_scheduled_date).days > 14:
                eligible_movies.append(m)  # Movie can be scheduled again

        T = range(k*34, (k*34)+34)

        prob, decision_vars =  model(T, movies, our_channel)

        prob.solve()
        
        scheduled_movies, used_movie_ids, schedule_df = get_sched(prob,movies,decision_vars)

# Apply the 14-day constraint here
        valid_scheduled_movies = []
        valid_used_movie_ids = []
        
        for m, movie in zip(used_movie_ids, scheduled_movies):
            movie_date = movie['Start Time']
            # Check if this movie has been scheduled in the last 14 days
            if m not in scheduled_dates:
                scheduled_dates[m] = []
            
            # Filter out movies scheduled in the past 14 days
            if all((pd.to_datetime(movie_date) - pd.to_datetime(d)).days > 14 for d in scheduled_dates[m]):
                scheduled_dates[m].append(movie_date)  # Add the current movie date to the list
                valid_scheduled_movies.append(movie)
                valid_used_movie_ids.append(m)
                
            thang.append(valid_scheduled_movies)
    
        for i in used_movie_ids:
            movies.drop(i, inplace = True)
        total_schedule.append(scheduled_movies)

    pd.concat([full_sched, schedule_df])
    return full_sched
    print(full_sched)

# %%
two_day = movie_sched(number_days=num_days, movies=movies_small, our_channel=ch_A_schedule_30min)
# Out:
# FICO Xpress v9.4.2, Hyper, solve started 22:02:19, Nov 21, 2024
# Heap usage: 23MB (peak 23MB, 43MB system)
# Maximizing MILP Movie_Scheduling_Problem using up to 12 threads and up to 7528MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      52849 rows        35713 cols       139331 elements     18611 entities
# Presolved problem has:
#      35244 rows        18611 cols       104624 elements     18611 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 36MB (peak 56MB, 43MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 3.31e-02,  1.57e+05] / [ 1.56e-02,  1.97e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.02e+02] / [ 1.00e+00,  1.02e+02]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 3.31e-02,  1.57e+05]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 15, support set: 851
#  Number of orbits: 296, largest orbit: 4
#  Row orbits: 560, row support: 1610
# Will try to keep branch and bound tree memory usage below 5.1GB
# Starting concurrent solve with dual (1 thread) and barrier (11 threads)
#
#               Concurrent-Solve,   1s
#             Dual                      Barrier
#     objective   sum inf
#  P  3361539.7   .0000000 |
#                          |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 240 simplex iterations, 0.04s
#         Barrier: 0 barrier and 0 simplex iterations, 0.05s
#             Barrier used 11 threads 6 cores
#             Barrier used AVX2 support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    240       3361539.689      P      0     0        .000000     1
# Dual solved problem
#   240 simplex iterations in 0.06 seconds at time 1
#
# Final objective                       : 3.361539688621064e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K                3359703.105      0    181      0               47      2
#    2  K                3358311.412      0    186    154               62      2
#    3  K                3357425.251      0    268    173               73      2
#    4  K                3356355.017      0    295    241              119      2
#    5  K                3355803.613      0    217    292               71      3
#    6  K                3355125.750      0    394    212              115      3
#    7  K                3354666.638      0    296    378              107      3
#    8  K                3354479.510      0    366    291              100      3
#    9  K                3354328.875      0    210    364               88      3
# b         3284345.866  3354287.672      1                  2.09%       0      4
# R         3300325.032  3354287.672      2                  1.61%       0      4
# R         3301577.633  3354287.672      3                  1.57%       0      4
#   10  K   3301577.633  3354287.672      3    263    214    1.57%      57      4
#   11  K   3301577.633  3354267.790      3     66    258    1.57%      19      4
#   12  K   3301577.633  3354028.888      3    530     72    1.56%     135      4
#   13  K   3301577.633  3353937.752      3    153    521    1.56%      63      4
#   14  K   3301577.633  3353702.272      3    544    152    1.55%     142      4
#   15  K   3301577.633  3353660.114      3    411    916    1.55%     104      5
# b         3321545.761  3353572.737      4                  0.96%       0      5
#   16  G   3321545.761  3353572.737      4    364     22    0.96%     159      5
#   17  G   3321545.761  3353530.999      4    173    530    0.95%     113      5
#
# Cuts in the matrix         : 127
# Cut elements in the matrix : 21049
#
# Performing root presolve...
#
# Reduced problem has:   24087 rows   12919 columns     84447 elements
# Presolve dropped   :   11284 rows    5692 columns     41226 elements
# Presolve tightened :       770 elements
# Symmetric problem: generators: 9, support set: 474
#  Number of orbits: 163, largest orbit: 4
#  Row orbits: 306, row support: 892
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 658 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   3271       794017205.6      D  11467     0        .000000     6
#   3384       3361539.689      P      0     0        .000000     6
# Optimal solution found
# Dual solved problem
#   3384 simplex iterations in 0.02 seconds at time 6
#
# Final objective                       : 3.361539688621064e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a         3348804.277  3353495.721      5                  0.14%       0      6
#    1  K   3348804.277  3353495.721      5    211     13    0.14%      95      6
#
# Cuts in the matrix         : 325
# Cut elements in the matrix : 47264
#
# Performing root presolve...
#
# Reduced problem has:    3035 rows    1451 columns     14983 elements
# Presolve dropped   :   21250 rows   11468 columns    103245 elements
# Presolve tightened :       645 elements
# Symmetric problem: generators: 6, support set: 190
#  Number of orbits: 70, largest orbit: 4
#  Row orbits: 132, row support: 357
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 84 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   4159       103519352.9      D   1062     0        .000000     6
#   4271       3361537.648      P      0     0        .000000     6
# Optimal solution found
# Dual solved problem
#   4271 simplex iterations in 0.00 seconds at time 6
#
# Final objective                       : 3.361537647555640e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R         3350787.549  3353457.209      6                  0.08%       0      7
# R         3350871.876  3353457.209      7                  0.08%       0      7
# R         3351633.960  3353457.209      8                  0.05%       0      7
# R         3352040.149  3353457.209      9                  0.04%       0      7
#    1  K   3352040.149  3353457.209      9    120    223    0.04%      98      7
#
# Cuts in the matrix         : 220
# Cut elements in the matrix : 9553
#
# Performing root presolve...
#
# Reduced problem has:     712 rows     297 columns      3649 elements
# Presolve dropped   :    2220 rows    1154 columns     13846 elements
# Presolve tightened :       536 elements
# Symmetric problem: generators: 4, support set: 74
#  Number of orbits: 20, largest orbit: 4
#  Row orbits: 33, row support: 126
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 35 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   5222       30972424.27      D    228     0        .000000     7
#   5326       3361018.520      P      0     0        .000000     7
# Optimal solution found
# Dual solved problem
#   5326 simplex iterations in 0.00 seconds at time 7
#
# Final objective                       : 3.361018520414639e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 2.013e-11 / 1.678e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3352040.149  3353299.012      9    107    120    0.04%      66      7
#    2  K   3352040.149  3353279.019      9    119    206    0.04%      29      7
#
# Cuts in the matrix         : 79
# Cut elements in the matrix : 374
#
# Performing root presolve...
#
# Reduced problem has:     399 rows     179 columns      1222 elements
# Presolve dropped   :     213 rows     118 columns       675 elements
# Presolve tightened :       191 elements
# Symmetric problem: generators: 2, support set: 32
#  Number of orbits: 16, largest orbit: 2
#  Row orbits: 25, row support: 50
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 19 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   6263       18040492.94      D     99     0        .000000     7
#   6340       3359483.066      P      0     0        .000000     7
# Optimal solution found
# Dual solved problem
#   6340 simplex iterations in 0.00 seconds at time 7
#
# Final objective                       : 3.359483065730039e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3352040.149  3353279.019      9     71     20    0.04%      21      7
#    2  K   3352040.149  3353279.019      9     28     96    0.04%       3      7
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 54
# Cut elements in the matrix : 231
#
# Starting tree search.
# Deterministic mode with up to 12 running threads and up to 32 tasks.
# Heap usage: 72MB (peak 128MB, 49MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3352040.149  3353237.757      9      2      1    0.04%      28      7
#        2  3352040.149  3353237.757      9      2      3    0.04%      30      7
#        3  3352040.149  3353124.711      9      3      4    0.03%      26      7
#        4  3352040.149  3353124.711      9      4      4    0.03%      75      7
#        5  3352040.149  3353124.711      9      5      5    0.03%      11      7
#        6  3352040.149  3353124.711      9      6      5    0.03%      11      7
#        7  3352040.149  3353124.711      9      5      5    0.03%      16      7
#        9  3352040.149  3353124.711      9      6      6    0.03%      13      7
#       10  3352040.149  3353124.711      9      6      3    0.03%      62      7
#       20  3352040.149  3352993.402      9      9      6    0.03%       1      7
#       30  3352040.149  3352993.402      9      8      8    0.03%      21      7
#       41  3352040.149  3352993.402      9      7      8    0.03%      25      7
#       51  3352040.149  3352993.402      9      4      9    0.03%      11      7
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.352040149480775e+06
# Final MIP bound                       : 3.352043501520924e+06
#   Solution time / primaldual integral :      7.74s/ 52.161351%
#   Number of solutions found / nodes   :         9 /        59
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# Scheduled Movies in Order:
#    Time Slot         Day Start Time End Time  Movie Index  \
# 0          0  2024-10-01      07:00    10:00           47
# 1          6  2024-10-01      10:00    13:00          172
# 2         12  2024-10-01      13:00    15:30          426
# 3         17  2024-10-01      15:30    19:00           71
# 4         24  2024-10-01      19:00    22:00           23
# 5         30  2024-10-01      22:00    07:00          326
#
#                                          Movie Title  movie_budget
# 0  Pirates of the Caribbean: The Curse of the Bla...     140000000
# 1                                  Blade Runner 2049     150000000
# 2                                         Real Steel     110000000
# 3                  The Hobbit: An Unexpected Journey     250000000
# 4                            Avengers: Age of Ultron     365000000
# 5                                  Godzilla vs. Kong     200000000
# FICO Xpress v9.4.2, Hyper, solve started 22:02:35, Nov 21, 2024
# Heap usage: 23MB (peak 23MB, 43MB system)
# Maximizing MILP Movie_Scheduling_Problem using up to 12 threads and up to 7528MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      52219 rows        35287 cols       137669 elements     18389 entities
# Presolved problem has:
#      34824 rows        18389 cols       103376 elements     18389 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 36MB (peak 56MB, 43MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 3.31e-02,  1.56e+05] / [ 1.56e-02,  1.97e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.02e+02] / [ 1.00e+00,  1.02e+02]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 3.31e-02,  1.56e+05]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 13, support set: 740
#  Number of orbits: 259, largest orbit: 4
#  Row orbits: 490, row support: 1400
# Will try to keep branch and bound tree memory usage below 5.1GB
#  *** Solution found:  3039295.276   Time:   1.01    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (11 threads)
#
#               Concurrent-Solve,   1s
#             Dual                      Barrier
#     objective   sum inf
#  P  3352190.8   .0000000 |
#                          |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 113 simplex iterations, 0.04s
#         Barrier: 0 barrier and 0 simplex iterations, 0.05s
#             Barrier used 11 threads 6 cores
#             Barrier used AVX2 support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    113       3352190.781      P      0     0        .000000     1
# Dual solved problem
#   113 simplex iterations in 0.06 seconds at time 1
#
# Final objective                       : 3.352190780517927e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 1.122e-10 / 7.479e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a         3334648.965  3352190.781      2                  0.52%       0      1
#
# Performing root presolve...
#
# Reduced problem has:   14150 rows    7651 columns     41829 elements
# Presolve dropped   :   20674 rows   10738 columns     61547 elements
# Presolve tightened :      4063 elements
# Symmetric problem: generators: 7, support set: 271
#  Number of orbits: 88, largest orbit: 4
#  Row orbits: 166, row support: 514
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 572 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#    261       406951678.1      D   4869     0        .000000     1
#    354       3352190.781      P      0     0        .000000     1
# Optimal solution found
# Dual solved problem
#   354 simplex iterations in 0.01 seconds at time 1
#
# Final objective                       : 3.352190780517925e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3334648.965  3350795.136      2    286      0    0.48%      58      2
# k         3334687.838  3350583.834      3                  0.47%       0      2
#    2  K   3334687.838  3350583.834      3    177    256    0.47%      50      2
#    3  K   3334687.838  3350022.159      3    211    176    0.46%      66      2
#    4  K   3334687.838  3349444.693      3    282    197    0.44%      74      2
#    5  K   3334687.838  3348233.309      3    212    275    0.40%      57      2
#    6  K   3334687.838  3348089.129      3     58    208    0.40%      15      2
#    7  K   3334687.838  3347935.479      3    185     62    0.40%      89      2
#    8  K   3334687.838  3347880.644      3     81    180    0.39%      30      2
#    9  K   3334687.838  3347858.924      3     14     78    0.39%      15      2
#   10  K   3334687.838  3347743.210      3     27     13    0.39%       1      2
#   11  K   3334687.838  3347684.759      3    325     30    0.39%     102      2
#   12  K   3334687.838  3347657.859      3     10    319    0.39%       2      2
#   13  K   3334687.838  3347492.883      3    379     17    0.38%      91      2
#   14  K   3334687.838  3347482.582      3    162    372    0.38%      25      3
#   15  K   3334687.838  3347417.082      3    377    474    0.38%      61      3
#
# Cuts in the matrix         : 129
# Cut elements in the matrix : 1439
#
# Performing root presolve...
#
# Reduced problem has:    5354 rows    2707 columns     16414 elements
# Presolve dropped   :    8925 rows    4944 columns     26854 elements
# Presolve tightened :       251 elements
# Symmetric problem: generators: 5, support set: 199
#  Number of orbits: 58, largest orbit: 4
#  Row orbits: 112, row support: 384
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 152 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   1302       202207791.5      D   2435     0        .000000     3
#   1398       3352184.460      P      0     0        .000000     3
# Optimal solution found
# Dual solved problem
#   1398 simplex iterations in 0.00 seconds at time 3
#
# Final objective                       : 3.352184459995416e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 1.216e-26 / 1.145e-26
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3334687.838  3347341.875      3     86     75    0.38%      28      3
#    2  K   3334687.838  3347225.714      3    294    342    0.37%      89      3
# P         3337296.551  3347225.714      4                  0.30%       0      3
#
# Cuts in the matrix         : 90
# Cut elements in the matrix : 2087
#
# Performing root presolve...
#
# Reduced problem has:    3596 rows    1884 columns     11901 elements
# Presolve dropped   :    1720 rows     823 columns      5354 elements
# Presolve tightened :       293 elements
# Symmetric problem: generators: 5, support set: 191
#  Number of orbits: 56, largest orbit: 4
#  Row orbits: 104, row support: 354
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 93 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   2577       150123733.7      D   1555     0        .000000     3
#   2668       3352184.460      P      0     0        .000000     3
# Optimal solution found
# Dual solved problem
#   2668 simplex iterations in 0.00 seconds at time 3
#
# Final objective                       : 3.352184459995416e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 1.216e-26 / 1.145e-26
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# P         3340545.231  3347225.714      5                  0.20%       0      3
# P         3341270.947  3347225.714      6                  0.18%       0      3
# R         3342037.317  3347178.234      7                  0.15%       0      3
# R         3343444.295  3347178.234      8                  0.11%       0      3
#    1  K   3343444.295  3347178.234      8    131     35    0.11%      34      4
#
# Cuts in the matrix         : 186
# Cut elements in the matrix : 9762
#
# Performing root presolve...
#
# Reduced problem has:    1640 rows     770 columns      8465 elements
# Presolve dropped   :    2052 rows    1114 columns     11610 elements
# Presolve tightened :       327 elements
# Symmetric problem: generators: 2, support set: 96
#  Number of orbits: 32, largest orbit: 3
#  Row orbits: 62, row support: 186
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 49 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   3193       65046786.20      D    668     0        .000000     4
#   3297       3351948.366      P      0     0        .000000     4
# Optimal solution found
# Dual solved problem
#   3297 simplex iterations in 0.00 seconds at time 4
#
# Final objective                       : 3.351948365757036e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3343444.295  3347076.196      8    180    135    0.11%      60      4
#    2  K   3343444.295  3346758.351      8    292    428    0.10%      94      4
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 94
# Cut elements in the matrix : 816
#
# Starting tree search.
# Deterministic mode with up to 12 running threads and up to 32 tasks.
# Heap usage: 69MB (peak 137MB, 49MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3343444.295  3346744.661      8      2      1    0.10%      83      4
#        2  3343444.295  3346744.661      8      2      2    0.10%      83      4
#        3  3343444.295  3346731.553      8      1      3    0.10%      67      4
#        4  3343444.295  3346657.759      8      2      4    0.10%       7      4
#        5  3343444.295  3346645.411      8      3      4    0.10%      81      4
#        6  3343444.295  3346645.411      8      4      5    0.10%      41      4
#        7  3343444.295  3346645.411      8      5      5    0.10%      87      4
#        8  3343444.295  3346528.541      8      6      5    0.09%      72      4
#        9  3343444.295  3346528.541      8      5      5    0.09%      24      4
#       10  3343444.295  3346528.541      8      6      6    0.09%      77      4
#       20  3343444.295  3346464.097      8     12      6    0.09%      53      4
#       30  3343444.295  3346452.280      8     14      8    0.09%      57      4
# a     32  3344022.950  3346452.280      9     14      8    0.07%       0      4
#       41  3344022.950  3346452.280      9     11      8    0.07%      31      4
#       52  3344022.950  3346444.908      9      9      7    0.07%      66      4
#       62  3344022.950  3346444.908      9      9      9    0.07%       8      4
#       72  3344022.950  3346098.538      9     11     10    0.06%      28      4
#       82  3344022.950  3346098.538      9     10     10    0.06%      17      4
#       92  3344022.950  3346098.538      9      9      6    0.06%       1      4
# Elapsed time (sec): 4, estimated tree completion: 0.97024
# Heap usage: 502MB (peak 502MB, 57MB system)
# B&B tree size: 206k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      102  3344022.950  3345925.808      9      7     11    0.06%      52      4
# g    112  3344866.171  3345925.808     10      4     12    0.03%       0      5
# g    115  3345310.910  3345925.808     11      3     14    0.02%       0      5
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=7.04796e-05).
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=7.04796e-05).
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.345310909560798e+06
# Final MIP bound                       : 3.345546702253595e+06
#   Solution time / primaldual integral :      5.06s/ 24.035698%
#   Number of solutions found / nodes   :        11 /       121
#   Max primal violation      (abs/rel) : 1.990e-13 / 1.421e-14
#   Max integer violation     (abs    ) : 1.990e-13
# Scheduled Movies in Order:
#    Time Slot         Day Start Time End Time  Movie Index  \
# 0         34  2024-10-02      07:00    10:30          143
# 1         41  2024-10-02      10:30    13:00          460
# 2         46  2024-10-02      13:00    15:30          373
# 3         50  2024-10-02      15:00    17:30          524
# 4         56  2024-10-02      18:00    21:00            4
# 5         62  2024-10-02      21:00    07:00            6
#
#                                  Movie Title  movie_budget
# 0   Pirates of the Caribbean: At World's End     300000000
# 1                        Fifty Shades Darker      55000000
# 2  The Twilight Saga: Breaking Dawn - Part 1     110000000
# 3      Fast & Furious Presents: Hobbs & Shaw     200000000
# 4                               The Avengers     220000000
# 5                     Avengers: Infinity War     300000000

# %%
# import numpy as np
# import pandas as pd

# def calculate_ad_slot_price(schedule_df: pd.DataFrame, base_fee: float,
#                             profit_margin: float, budget_factor: float,
#                             box_office_factor: float) -> pd.Series:
#     '''
#     Works out the cost required to buy a specific ad slot.  This is based on the time
#     of day, and the budget/earnings of the movie being shown before the
#     chosen ad slot.

#     This function is applied to a schedule dataframe to create a new column
#     containing the ad slot prices, returns NaN if the slot is not an ad slot.

#     This is also multiplied by the prime time factor, desired profit margin does
#     not take into account the effects of prime time factor currently, i.e.
#     there'll be a larger profit margin obtained than the one specified for spots
#     in prime time.

#     Values used in generation of dataset.
#     base_fee = 10_000
#     profit_margin = 0.2
#     budget_factor = 0.002
#     box_office_revenue_factor = 0.001

#     :param schedule_df: Dataframe containing the populated schedule with movies and
#                       : ad breaks.
#     :param base_fee: Base fee required for all movies to be licensed to a channel
#     :param profit_margin: Percent (in 0-1 scale) of license fee that the channel
#                         : wants to make in profit.
#     :param budget_factor: What percent (in 0-1 scale) of the movie's budget contributes
#                         : to the license fee.
#     :param box_office_factor: What percent (in 0-1 scale) of the movie's box office renvenue
#                             : contributes to the license fee.
#     '''

#     license_fee = (base_fee
#                    + (budget_factor * schedule_df.movie_budget)
#                    + (box_office_factor * schedule_df.box_office_revenue)
#                    ) * (1. + profit_margin)

#     ad_slot_cost = (license_fee / schedule_df.n_ad_breaks) * schedule_df.prime_time_factor

#     # return np.round(ad_slot_cost, 2)
#     return license_fee

# %%
# calculate_ad_slot_price(schedule_df= two_day, base_fee= 10_000, profit_margin= 0.2, budget_factor=0.002,box_office_factor=0.001)
