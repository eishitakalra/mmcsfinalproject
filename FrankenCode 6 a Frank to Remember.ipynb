# %%
# Import packages and read-in files

import numpy as np
import pandas as pd
import xpress as xp
from datetime import datetime, timedelta
import os
import math 

# Read in files using the explicitly defined base path
ch_0_conversion_rates = pd.read_csv('channel_0_conversion_rates.csv')
ch_0_schedule = pd.read_csv('channel_0_schedule.csv')
ch_1_conversion_rates = pd.read_csv('channel_1_conversion_rates.csv')
ch_1_schedule = pd.read_csv('channel_1_schedule.csv')
ch_2_conversion_rates = pd.read_csv('channel_2_conversion_rates.csv')
ch_2_schedule = pd.read_csv('channel_2_schedule.csv')
ch_A_schedule = pd.read_csv('channel_A_schedule.csv')
movies_df = pd.read_csv('movie_database.csv')

# %%
# To use right xpress and get rid of unnecessary error codes
xp.init('C:/xpressmp/bin/xpauth.xpr')
pd.options.mode.copy_on_write = True
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Formatting of all dataframes

# %%
# FORMATING
# Convert 'Date-Time' columns to datetime format
date_cols = ['Date']

for df in [ch_0_conversion_rates, ch_0_schedule, ch_1_conversion_rates, ch_1_schedule,
           ch_2_conversion_rates, ch_2_schedule, ch_A_schedule]:
    df['Date'] = pd.to_datetime(df['Unnamed: 0'])
    df.set_index('Date', inplace=True)
    df.drop('Unnamed: 0', axis=1, inplace = True)
   

# Convert 'Release Date' in movie_database to datetime
movies_df['release_date'] = pd.to_datetime(movies_df['release_date'])

# Fill missing values if necessary
movies_df.fillna(0, inplace=True)

# %%
# Put all dataframes into 30-min slots instead of 5-min slots

# Ch A 30 min compressing
from datetime import time

# Resample to 30-minute intervals (use mean of groups)
ch_A_schedule_30min = ch_A_schedule.resample('30T').mean().reset_index()

# Define start and end times for filtering
daily_start_time = time(7, 0)  # 7:00 AM
daily_end_time = time(23, 30)  # 11:55 PM

# Filter rows to include only time slots within the desired range 
ch_A_schedule_30min['time'] = ch_A_schedule_30min['Date'].dt.time
ch_A_schedule_30min = ch_A_schedule_30min[
    (ch_A_schedule_30min['time'] >= daily_start_time) &
    (ch_A_schedule_30min['time'] <= daily_end_time)
].drop(columns=['time'])
ch_A_schedule_30min.reset_index(inplace = True)
ch_A_schedule_30min.drop('index', axis = 1,inplace = True)

# Ch 0 30 min compressing
from datetime import time
ch_0 = pd.DataFrame(ch_0_schedule['ad_slot_price'])


# Resample to 30-minute intervals (use mean of groups)
ch_0_schedule_30min = ch_0.resample('30T').mean().reset_index()

# Define start and end times for filtering
daily_start_time = time(7, 0)  # 7:00 AM
daily_end_time = time(23, 55)  # 11:55 PM

# Filter rows to include only time slots within the desired range 
ch_0_schedule_30min['time'] = ch_0_schedule_30min['Date'].dt.time
ch_0_schedule_30min = ch_0_schedule_30min[
    (ch_0_schedule_30min['time'] >= daily_start_time) &
    (ch_0_schedule_30min['time'] <= daily_end_time)
].drop(columns=['time'])
ch_0_schedule_30min.reset_index(inplace = True)
ch_0_schedule_30min.drop('index', axis = 1,inplace = True)

# Ch 1 30 min compressing
from datetime import time
ch_1 = pd.DataFrame(ch_1_schedule['ad_slot_price'])


# Resample to 30-minute intervals (use mean of groups)
ch_1_schedule_30min = ch_1.resample('30T').mean().reset_index()

# Define start and end times for filtering
daily_start_time = time(7, 0)  # 7:00 AM
daily_end_time = time(23, 55)  # 11:55 PM

# Filter rows to include only time slots within the desired range 
ch_1_schedule_30min['time'] = ch_1_schedule_30min['Date'].dt.time
ch_1_schedule_30min = ch_1_schedule_30min[
    (ch_1_schedule_30min['time'] >= daily_start_time) &
    (ch_1_schedule_30min['time'] <= daily_end_time)
].drop(columns=['time'])
ch_1_schedule_30min.reset_index(inplace = True)
ch_1_schedule_30min.drop('index', axis = 1,inplace = True)

# Ch 2 30 min compressing
from datetime import time
ch_2 = pd.DataFrame(ch_2_schedule['ad_slot_price'])


# Resample to 30-minute intervals (use mean of groups)
ch_2_schedule_30min = ch_2.resample('30T').mean().reset_index()

# Define start and end times for filtering
daily_start_time = time(7, 0)  # 7:00 AM
daily_end_time = time(23, 55)  # 11:55 PM

# Filter rows to include only time slots within the desired range 
ch_2_schedule_30min['time'] = ch_2_schedule_30min['Date'].dt.time
ch_2_schedule_30min = ch_2_schedule_30min[
    (ch_2_schedule_30min['time'] >= daily_start_time) &
    (ch_2_schedule_30min['time'] <= daily_end_time)
].drop(columns=['time'])

ch_2_schedule_30min.reset_index(inplace = True)
ch_2_schedule_30min.drop('index', axis = 1,inplace = True)

# %% [markdown]
# # Getting Movie dataframe together

# %%
# Slot duration 30 minutes
slot_duration = 30  # minutes
movies_df['slots_needed'] = (movies_df['runtime_with_ads'] / slot_duration).apply(lambda x: int(x)).astype(int)

# %%
# Check for duplicate movie titles
duplicate_titles = movies_df[movies_df.duplicated(subset=['title'], keep=False)]
if not duplicate_titles.empty:
    print("Duplicate movie titles found:")
    print(duplicate_titles['title'])
else:
    print("No duplicate movie titles found.")
# Out:
# Duplicate movie titles found:
# 4                 The Avengers
# 17                     Titanic
# 76               The Lion King
# 105       Beauty and the Beast
# 149        Alice in Wonderland
#                  ...
# 5748              Midnight Sun
# 5761                The Island
# 5773            The Shaggy Dog
# 5855    Fun with Dick and Jane
# 5879        The Perfect Weapon
# Name: title, Length: 258, dtype: object

# %% [markdown]
# ## Choose Number of Days and Movies, then format time slots and datetime layout
# Specify how many movies you want to practice code with and how many days you want schedule to be created for

# %%
####
# Specify size of small_movies to practice and debug
movies_small = movies_df.head(550)

# make copy for movie info later since the model takes the movie titles out of movies_small
movies_copy = movies_small.copy(deep=True)

# change num_days based on number of days you want the scheduling function to create
num_days = 3

# %%
# create time slots and whatnot

from datetime import datetime, timedelta
# Define the broadcasting start and end dates
broadcast_start_date = datetime.strptime("2024-10-01", "%Y-%m-%d")
broadcast_end_date = broadcast_start_date + timedelta(days=num_days)  # 7 days including start date

# Define daily broadcast start and end times
daily_broadcast_start_time = timedelta(hours=7, minutes=0)
daily_broadcast_end_time = timedelta(hours=23, minutes=30)

# Generate all time slots over the date range
time_slots = []
current_date = broadcast_start_date
while current_date <= broadcast_end_date:
    # Set the start and end times for the current day
    day_start = datetime.combine(current_date.date(), datetime.min.time()) + daily_broadcast_start_time
    day_end = datetime.combine(current_date.date(), datetime.min.time()) + daily_broadcast_end_time
    
    current_time = day_start
    while current_time <= day_end:
        time_slots.append(current_time)
        current_time += timedelta(minutes=slot_duration)
    
    # Move to the next day
    current_date += timedelta(days=1)

# Create mappings between time slots and indices
time_to_index = {t: idx for idx, t in enumerate(time_slots)}
index_to_time = {idx: t for idx, t in enumerate(time_slots)}

# %% [markdown]
# # Function to calculate viewership of each movie (will be used in objective function)

# %%
# Function to find viewership of each movie based on popularity of each demographic
def get_views(m, t_idx, movies, our_channel):
    # Baseline viewership at time slot t_idx
    baseline = {
        'children': our_channel.iloc[t_idx]['children_baseline_view_count'],
        'adults': our_channel.iloc[t_idx]['adults_baseline_view_count'],
        'retirees': our_channel.iloc[t_idx]['retirees_baseline_view_count']
    }
    
    # Scaled popularity of movie m
    popularity = {
        'children': movies.loc[m, 'children_scaled_popularity'],
        'adults': movies.loc[m, 'adults_scaled_popularity'],
        'retirees': movies.loc[m, 'retirees_scaled_popularity']
    }
    
    # Calculate expected viewership (assuming total population of 1,000,000)
    total_population = 1_000_000
    viewership = sum(
        baseline[demo] * popularity[demo] * total_population
        for demo in ['children', 'adults', 'retirees']
    )
    
    return viewership

# %% [markdown]
# # The Model

# %%
# Function to create xpress problem, decision vars, and objective function
# to maximize viewership
def model(T, movies, our_channel):
    prob = xp.problem(name="Movie_Scheduling_Problem")
    
    # Constants
    slots_per_day = 34  # Number of slots per day (e.g., from 07:00 to 23:30)
    days = len(time_slots) // slots_per_day  # Number of days in the schedule
    M = len(time_slots)  # Big M for constraints
    T_end = len(time_slots) - 1  # Last time slot index

    
    # Decision Variables
    x = {(m, t): xp.var(vartype=xp.binary, name='x_{0}_{1}'.format(m, t)) 
         for m in movies.index for t in T}
    prob.addVariable(list(x.values()))
    
    y = {m: xp.var(vartype=xp.binary, name='y_{0}'.format(m)) for m in movies.index}
    prob.addVariable(list(y.values()))
 
    
    s = {m: xp.var(vartype=xp.integer, name='s_{0}'.format(m)) for m in movies.index}
    e = {m: xp.var(vartype=xp.integer, name='e_{0}'.format(m)) for m in movies.index}
    prob.addVariable(list(s.values()))
    prob.addVariable(list(e.values()))
    
    u = {(m, t): xp.var(vartype=xp.continuous, name='u_{0}_{1}'.format(m, t)) 
         for m in movies.index for t in T}
    prob.addVariable(list(u.values()))
    
    decision_vars = [x, y, s, e]

    # Constraints
    # 1. Movie Duration Constraint
    for m in movies.index:
        prob.addConstraint(
            xp.Sum(x[m, t] for t in T) == movies.loc[m, 'slots_needed'] * y[m]
        )
    # 2. Time Slot Occupancy Constraint
    for t in T:
        prob.addConstraint(
            xp.Sum(x[m, t] for m in movies.index) == 1
        )
    # 3. Start Time Constraints
    for m in movies.index:
        for t in T:
            prob.addConstraint(
                s[m] <= t * x[m, t] + (1 - x[m, t]) * M
            )
    # 4. End Time Constraints
    for m in movies.index:
        for t in T:
            prob.addConstraint(
                e[m] >= (t + 1) * x[m, t]
            )
    # 5. Movie Duration Relationship Constraint
    for m in movies.index:
        prob.addConstraint(
            e[m] - s[m] == movies.loc[m, 'slots_needed'] * y[m]
        )
    # 6 last movie ends at midnight
    prob.addConstraint(s[m] + movies.loc[m, 'slots_needed'] -1 <= T_end for m in movies.index)
    # 7. View Count Constraints
    for m in movies.index:
        for t_idx, t in enumerate(T):
            expected_viewership = get_views(m, t_idx, movies, our_channel)
            prob.addConstraint(
                u[m, t] == expected_viewership * x[m, t]
            )
    # 9. Objective Function
    prob.setObjective(
        xp.Sum(u[m, t] for m in movies.index for t in T),
        sense=xp.maximize
    )
    
    return prob, decision_vars

# %%
# Making schedule layout
def get_time(slot_index):
    return time_slots[slot_index].time()

used_movie_ids = []
def get_sched(prob, movies, decision_vars): 
    
    x = decision_vars[0]
    y = decision_vars[1]
    s = decision_vars[2]
    e = decision_vars[3]
    
    scheduled_movies = []
    used_movie_ids = []

    for m_idx, m_row in movies.iterrows():
        y_value = prob.getSolution(y[m_idx])
        if y_value > 0.5:  # Movie is scheduled
            used_movie_ids.append(m_idx)
            start_slot = int(prob.getSolution(s[m_idx]))
            end_slot = int(prob.getSolution(e[m_idx]))
    
            # Ensure the end slot is valid
            if end_slot < len(time_slots):
                # Get the corresponding day and times
                start_time = time_slots[start_slot]
                end_time = time_slots[end_slot]
                day = start_time.strftime('%Y-%m-%d')
                start_time_formatted = start_time.strftime('%H:%M')
                end_time_formatted = end_time.strftime('%H:%M')
    
                # Append the movie schedule
                scheduled_movies.append({
                    'Time Slot': start_slot,
                    'Day': day,
                    'Start Time': start_time_formatted,
                    'End Time': end_time_formatted,
                    'Movie Index': m_idx,
                    'Movie Title': m_row['title'], 
                    'num_slots': m_row['slots_needed'],
                    'movie_budget': m_row['budget'],
                    'box_office_revenue': m_row['revenue'],
                    'n_ad_breaks': m_row['n_ad_breaks']
                })
    # Convert to a DataFrame for better organization
    schedule_df = pd.DataFrame(scheduled_movies) 
    
    # Sort by day and time slot
    schedule_df.sort_values(by=['Day', 'Time Slot'], inplace=True)
    
    # Reset index for cleaner output
    schedule_df.reset_index(drop=True, inplace=True)

    # Print the schedule
    print("Scheduled Movies in Order:")
    print(schedule_df)

    return scheduled_movies, used_movie_ids, schedule_df

# %%
# Putting it all together

def movie_sched(number_days, movies, our_channel):
    used_movie_ids= []
    total_schedule = [] # list of 
    scheduled_dates = {}  # Dictionary to track when movies were scheduled by movie_id
    
    full_list = []
    flat_list = []
    for k in range(number_days):
        if k == 0:
            T = range(k*34, ((k*34)+33)+1)
    
            prob, decision_vars =  model(T, movies, our_channel)
    
            prob.solve()
            
            scheduled_movies, used_movie_ids, schedule_df = get_sched(prob,movies,decision_vars)
            
            # add scheduled movies to a list
            full_list.append(scheduled_movies)
    
        # take used movies out of df so we don't repeat movies
            for i in used_movie_ids:
                movies.drop(i, inplace = True)
            total_schedule.append(scheduled_movies)

        elif k > 0:
            # 34*3 = 102 but index at zero --> 3 days is rows 0-101
            # 34*2 = 68 (start of day 3)
            # Day 1: 0-33  ( +33)
            # Day 2: 34-67 ( +34)
            # Day 3: 68-102 ( +34)
            
            T = range(k*34, (k+1)*34)
    
            prob, decision_vars =  model(T, movies, our_channel)
    
            prob.solve()
            
            scheduled_movies, used_movie_ids, schedule_df = get_sched(prob,movies,decision_vars)
            
            # add scheduled movies to a list
            full_list.append(scheduled_movies)
    
        # take used movies out of df so we don't repeat movies
            for i in used_movie_ids:
                movies.drop(i, inplace = True)
            total_schedule.append(scheduled_movies)
        
    # unpack the list of list of dictionaries so we can make it into a df
    for i in full_list:
        for item in i:
            flat_list.append(item)
            
    # make df of all movies used for all days, ordered by day then by time slot        
    full_df = pd.DataFrame.from_dict(flat_list, orient='columns')
    full_df.sort_values(by=['Day', 'Time Slot'], inplace=True)
    full_df.reset_index(drop=True, inplace=True)
        
    print('full df:', full_df)
    return full_df

# %%
# Code to find licensings fee (cost to air each movie)
import numpy as np
import pandas as pd
movie_money_info = pd.DataFrame()

def calculate_license_price(schedule_df: pd.DataFrame) -> pd.Series:
    '''
    Works out the cost required to buy a specific ad slot.  This is based on the time
    of day, and the budget/earnings of the movie being shown before the
    chosen ad slot.

    This function is applied to a schedule dataframe to create a new column
    containing the ad slot prices, returns NaN if the slot is not an ad slot.

    This is also multiplied by the prime time factor, desired profit margin does
    not take into account the effects of prime time factor currently, i.e.
    there'll be a larger profit margin obtained than the one specified for spots
    in prime time.

    Values used in generation of dataset.
    base_fee = 10_000
    profit_margin = 0.2
    budget_factor = 0.002
    box_office_revenue_factor = 0.001

    :param schedule_df: Dataframe containing the populated schedule with movies and
                      : ad breaks.
    :param base_fee: Base fee required for all movies to be licensed to a channel
    :param profit_margin: Percent (in 0-1 scale) of license fee that the channel
                        : wants to make in profit.
    :param budget_factor: What percent (in 0-1 scale) of the movie's budget contributes
                        : to the license fee.
    :param box_office_factor: What percent (in 0-1 scale) of the movie's box office renvenue
                            : contributes to the license fee.
    '''

    # license_fee = (base_fee
    #                + (budget_factor * schedule_df.movie_budget)
    #                + (box_office_factor *schedule_df.box_office_revenue)
    #                ) * (1. + profit_margin)

    license_fee = (10_000
                   + (0.002 * schedule_df.movie_budget)
                   + (0.001 *schedule_df.box_office_revenue)
                   ) * (1. + 0.2)

    ad_slot_cost = (license_fee / schedule_df.n_ad_breaks) #* schedule_df.prime_time_factor
    
    movie_money_info['movie'] = schedule_df['Movie Title'] 
    movie_money_info['license_fee'] = round(license_fee,2)
    movie_money_info['cost_per_ad_slot_cost'] = round(ad_slot_cost,2)
    movie_money_info['num_slots'] = schedule_df['n_ad_breaks']

    # return np.round(ad_slot_cost, 2)
    return movie_money_info

# %% [markdown]
# # Find money information based on generated schedule (change num_days and size of movies_small if desired, but make sure you run all cells again)
# ## df returned from license_fee function is called "movie_money_info" and can be referenced later on in code

# %%
# test for 3 days 
# 
three_days = movie_sched(number_days = num_days, movies = movies_small, our_channel= ch_A_schedule_30min)
# Out:
# FICO Xpress v9.4.2, Hyper, solve started 13:23:36, Nov 24, 2024
# Heap usage: 29MB (peak 29MB, 9179KB system)
# Maximizing MILP Movie_Scheduling_Problem using up to 12 threads and up to 7528MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      57784 rows        39050 cols       152350 elements     20350 entities
# Presolved problem has:
#      38534 rows        20350 cols       114400 elements     20350 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 43MB (peak 68MB, 9179KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 3.31e-02,  1.71e+05] / [ 7.81e-03,  1.98e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.36e+02] / [ 1.00e+00,  1.36e+02]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 3.31e-02,  1.71e+05]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 24, support set: 1295
#  Number of orbits: 407, largest orbit: 7
#  Row orbits: 770, row support: 2450
# Will try to keep branch and bound tree memory usage below 257MB
#  *** Solution found:  3110460.087   Time:   1.11    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (11 threads)
#
#               Concurrent-Solve,   1s
#             Dual                      Barrier
#     objective   sum inf
#  P  3708945.8   .0000000 |
#                          |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 179 simplex iterations, 0.03s
#         Barrier: 0 barrier and 0 simplex iterations, 0.05s
#             Barrier used 11 threads 6 cores
#             Barrier used AVX2 support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    179       3708945.754      P      0     0        .000000     1
# Dual solved problem
#   179 simplex iterations in 0.07 seconds at time 1
#
# Final objective                       : 3.708945754020137e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R         3241977.162  3706545.149      2                 12.53%       0      1
# R         3295782.453  3706545.149      3                 11.08%       0      1
# R         3314913.252  3706545.149      4                 10.57%       0      2
# R         3501103.718  3706545.149      5                  5.54%       0      2
# R         3573018.409  3706545.149      6                  3.60%       0      2
#    1  K   3573018.409  3706545.149      6    292      0    3.60%      78      2
#    2  K   3573018.409  3705994.552      6    183    263    3.59%      58      2
#    3  K   3573018.409  3705893.104      6    257    176    3.59%      52      2
#    4  K   3573018.409  3705835.935      6    137    242    3.58%      49      2
#    5  K   3573018.409  3705711.600      6    217    134    3.58%      69      2
#    6  K   3573018.409  3705701.984      6    217    204    3.58%      41      2
#    7  K   3573018.409  3705646.738      6    424    213    3.58%      80      3
# q         3697023.672  3705590.616      7                  0.23%       0      3
#    8  K   3697023.672  3705590.616      7    536    428    0.23%      54      3
#
# Cuts in the matrix         : 603
# Cut elements in the matrix : 6470
#
# Performing root presolve...
#
# Reduced problem has:    3050 rows    1368 columns     12863 elements
# Presolve dropped   :   36087 rows   18982 columns    108007 elements
# Presolve tightened :      1230 elements
# Symmetric problem: generators: 14, support set: 289
#  Number of orbits: 98, largest orbit: 5
#  Row orbits: 174, row support: 506
# Will try to keep branch and bound tree memory usage below 118MB
# Crash basis containing 110 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   1310       84907098.73      D    839     0        .000000     3
#   1488       3708945.754      P      0     0        .000000     3
# Optimal solution found
# Dual solved problem
#   1488 simplex iterations in 0.01 seconds at time 3
#
# Final objective                       : 3.708945754020136e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R         3697369.510  3705484.443      8                  0.22%       0      3
#    1  K   3697369.510  3705484.443      8     40    536    0.22%      58      3
#    2  K   3697369.510  3705413.632      8    312     45    0.22%      71      3
#    3  K   3697369.510  3705399.881      8    497    297    0.22%     119      3
#    4  K   3697369.510  3705378.177      8     46    492    0.22%      60      3
#    5  K   3697369.510  3705311.946      8    530     52    0.21%     103      3
#    6  K   3697369.510  3705196.004      8    328    526    0.21%     119      3
#    7  K   3697369.510  3705186.886      8     65    385    0.21%      75      3
#
# Cuts in the matrix         : 81
# Cut elements in the matrix : 794
#
# Performing root presolve...
#
# Reduced problem has:    1024 rows     497 columns      3414 elements
# Presolve dropped   :    1511 rows     871 columns      4629 elements
# Presolve tightened :       461 elements
# Symmetric problem: generators: 3, support set: 78
#  Number of orbits: 36, largest orbit: 3
#  Row orbits: 65, row support: 139
# Will try to keep branch and bound tree memory usage below 127MB
# Crash basis containing 27 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   2888       54385639.29      D    454     0        .000000     3
#   3019       3708369.295      P      0     0        .000000     3
# Optimal solution found
# Dual solved problem
#   3019 simplex iterations in 0.00 seconds at time 3
#
# Final objective                       : 3.708369295123818e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3697369.510  3705052.882      8    130     20    0.21%      78      3
#    2  K   3697369.510  3705023.670      8     24    149    0.21%      54      3
# Heuristic search 'R' started
# Heuristic search 'R' stopped
# M         3700513.973  3705023.670      9                  0.12%       0      3
#
# Cuts in the matrix         : 60
# Cut elements in the matrix : 1000
#
# Performing root presolve...
#
# Reduced problem has:     584 rows     276 columns      2169 elements
# Presolve dropped   :     425 rows     221 columns      1559 elements
# Presolve tightened :       231 elements
# Symmetric problem: generators: 1, support set: 50
#  Number of orbits: 25, largest orbit: 2
#  Row orbits: 46, row support: 92
# Will try to keep branch and bound tree memory usage below 127MB
# Crash basis containing 14 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   3741       29957899.45      D    250     0        .000000     4
#   3871       3708275.888      P      0     0        .000000     4
# Optimal solution found
# Dual solved problem
#   3871 simplex iterations in 0.00 seconds at time 4
#
# Final objective                       : 3.708275887993966e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 5.821e-11 / 5.821e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3700513.973  3705021.972      9     99     10    0.12%      57      4
#    2  K   3700513.973  3704916.183      9    269    285    0.12%      96      4
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 133
# Cut elements in the matrix : 1074
#
# Starting tree search.
# Deterministic mode with up to 12 running threads and up to 32 tasks.
# Heap usage: 81MB (peak 166MB, 19MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3700513.973  3704894.298      9      2      1    0.12%      80      4
#        2  3700513.973  3704894.298      9      2      3    0.12%      52      4
# Will try to keep branch and bound tree memory usage below 58MB
#        4  3700513.973  3704894.298      9      3      4    0.12%      51      4
#        5  3700513.973  3704894.298      9      3      3    0.12%      99      4
# Will try to keep branch and bound tree memory usage below 35MB
#        6  3700513.973  3704833.007      9      4      4    0.12%      37      4
#        7  3700513.973  3704833.007      9      5      4    0.12%      28      4
# Will try to keep branch and bound tree memory usage below 5.1GB
#        8  3700513.973  3704833.007      9      4      5    0.12%      11      4
# q      8  3701797.171  3704833.007     10      5      5    0.08%       0      4
#        9  3701797.171  3704833.007     10      5      5    0.08%      11      4
#       10  3701797.171  3704833.007     10      4      4    0.08%      67      4
# q     16  3703506.962  3704819.600     11      6      5    0.04%       0      4
#       20  3703506.962  3704819.600     11      5      1    0.04%       2      4
#       32  3703506.962  3704819.600     11      2      5    0.04%      67      4
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.703506962496458e+06
# Final MIP bound                       : 3.703510666003420e+06
#   Solution time / primaldual integral :      4.59s/ 40.809718%
#   Number of solutions found / nodes   :        11 /        35
#   Max primal violation      (abs/rel) : 5.684e-14 / 2.887e-15
#   Max integer violation     (abs    ) : 2.887e-15
# Scheduled Movies in Order:
#    Time Slot         Day Start Time End Time  Movie Index  \
# 0          0  2024-10-01      07:00    09:30          539
# 1          5  2024-10-01      09:30    13:30           17
# 2         13  2024-10-01      13:30    16:30           10
# 3         19  2024-10-01      16:30    18:30           93
# 4         23  2024-10-01      18:30    22:00           22
# 5         30  2024-10-01      22:00    07:00          403
#
#                Movie Title  num_slots  movie_budget  box_office_revenue  \
# 0   Thor: Love and Thunder          5     250000000           760928081
# 1                  Titanic          8     200000000          2264162353
# 2             Forrest Gump          6      55000000           677387716
# 3             The Hangover          4      35000000           469310836
# 4  The Wolf of Wall Street          7     100000000           392000000
# 5                    After          4      14000000            69497587
#
#    n_ad_breaks
# 0            4
# 1            7
# 2            5
# 3            4
# 4            7
# 5            4
# FICO Xpress v9.4.2, Hyper, solve started 13:23:49, Nov 24, 2024
# Heap usage: 29MB (peak 29MB, 9199KB system)
# Maximizing MILP Movie_Scheduling_Problem using up to 12 threads and up to 7528MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      57154 rows        38624 cols       150688 elements     20128 entities
# Presolved problem has:
#      38114 rows        20128 cols       113152 elements     20128 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 43MB (peak 67MB, 9199KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 3.31e-02,  1.70e+05] / [ 1.56e-02,  1.97e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.36e+02] / [ 1.00e+00,  1.36e+02]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 3.31e-02,  1.70e+05]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 23, support set: 1221
#  Number of orbits: 370, largest orbit: 7
#  Row orbits: 700, row support: 2310
# Will try to keep branch and bound tree memory usage below 5.1GB
#  *** Solution found:  3129075.950   Time:   1.05    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (11 threads)
#
#               Concurrent-Solve,   1s
#             Dual                      Barrier
#     objective   sum inf
#  P  3668562.7   .0000000 |
#                          |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 245 simplex iterations, 0.05s
#         Barrier: 0 barrier and 0 simplex iterations, 0.06s
#             Barrier used 11 threads 6 cores
#             Barrier used AVX2 support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    245       3668562.693      P      0     0        .000000     1
# Dual solved problem
#   245 simplex iterations in 0.07 seconds at time 1
#
# Final objective                       : 3.668562692868193e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 7.276e-12 / 7.276e-12
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a         3634851.240  3668562.693      2                  0.92%       0      1
#
# Performing root presolve...
#
# Reduced problem has:   22040 rows   11998 columns     65644 elements
# Presolve dropped   :   16074 rows    8130 columns     47508 elements
# Presolve tightened :      3106 elements
# Symmetric problem: generators: 17, support set: 810
#  Number of orbits: 220, largest orbit: 7
#  Row orbits: 412, row support: 1524
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 699 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#    368       714873237.4      D   9909     0        .000000     2
#    587       3668562.693      P      0     0        .000000     2
# Optimal solution found
# Dual solved problem
#   587 simplex iterations in 0.02 seconds at time 2
#
# Final objective                       : 3.668562692868193e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 7.276e-12 / 7.276e-12
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3634851.240  3667737.980      2    478      0    0.90%      76      2
#    2  K   3634851.240  3667348.949      2    264    444    0.89%      64      2
#    3  K   3634851.240  3666960.525      2    451    267    0.88%      80      2
#    4  K   3634851.240  3666956.794      2    329    429    0.88%      75      2
# P         3636796.190  3666956.794      3                  0.82%       0      2
#    5  K   3636796.190  3666879.910      3    421    328    0.82%      76      2
#    6  K   3636796.190  3666611.292      3    661    418    0.81%      87      3
#    7  K   3636796.190  3666213.738      3    611    652    0.80%      95      3
#    8  K   3636796.190  3665733.584      3    624    606    0.79%      82      3
#    9  K   3636796.190  3665200.694      3    971    626    0.77%      95      3
#   10  K   3636796.190  3664524.797      3    927    948    0.76%     118      3
#   11  K   3636796.190  3664309.248      3    963    921    0.75%     105      3
#   12  K   3636796.190  3664039.581      3    616    958    0.74%     136      4
#   13  K   3636796.190  3663736.335      3    915    610    0.74%     126      4
#   14  K   3636796.190  3663531.166      3   1126    915    0.73%     144      4
#   15  K   3636796.190  3663376.894      3    830   1761    0.73%     120      4
#
# Cuts in the matrix         : 304
# Cut elements in the matrix : 3334
#
# Performing root presolve...
#
# Reduced problem has:   13085 rows    6865 columns     41011 elements
# Presolve dropped   :    9259 rows    5133 columns     27967 elements
# Presolve tightened :       747 elements
# Symmetric problem: generators: 16, support set: 762
#  Number of orbits: 196, largest orbit: 7
#  Row orbits: 369, row support: 1438
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 324 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   3395       488946015.9      D   6171     0        .000000     4
#   3588       3668562.693      P      0     0        .000000     4
# Optimal solution found
# Dual solved problem
#   3588 simplex iterations in 0.01 seconds at time 4
#
# Final objective                       : 3.668562692868193e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 1.527e-11 / 8.009e-12
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# q         3637366.688  3663376.894      4                  0.71%       0      4
#    1  K   3637366.688  3663308.795      4    267    201    0.71%      66      5
#    2  K   3637366.688  3662671.586      4    962    934    0.69%     130      5
# Heuristic search 'R' started
# Heuristic search 'R' stopped
# M         3641834.451  3662671.586      5                  0.57%       0      6
#
# Cuts in the matrix         : 398
# Cut elements in the matrix : 3635
#
# Performing root presolve...
#
# Reduced problem has:    9152 rows    4690 columns     29570 elements
# Presolve dropped   :    4027 rows    2175 columns     11863 elements
# Presolve tightened :       834 elements
# Symmetric problem: generators: 15, support set: 646
#  Number of orbits: 160, largest orbit: 7
#  Row orbits: 300, row support: 1212
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 216 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   4390       349694089.2      D   3656     0        .000000     8
#   4603       3668562.693      P      0     0        .000000     8
# Optimal solution found
# Dual solved problem
#   4603 simplex iterations in 0.01 seconds at time 8
#
# Final objective                       : 3.668562692868194e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 7.276e-12 / 7.276e-12
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3641834.451  3662401.454      5    285    283    0.56%     107      8
#    2  K   3641834.451  3662030.890      5   1075   1309    0.55%     120      9
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 166
# Cut elements in the matrix : 4335
#
# Starting tree search.
# Deterministic mode with up to 12 running threads and up to 32 tasks.
# Heap usage: 87MB (peak 150MB, 19MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3641834.451  3661898.742      5      2      1    0.55%     132     10
#        2  3641834.451  3661893.100      5      2      3    0.55%     113     11
#        3  3641834.451  3661874.150      5      3      3    0.55%      99     11
#        4  3641834.451  3661421.387      5      4      4    0.53%       9     11
#        5  3641834.451  3661421.387      5      5      4    0.53%      93     11
#        6  3641834.451  3661391.360      5      6      4    0.53%      88     11
#        7  3641834.451  3661391.360      5      7      4    0.53%      56     11
#        8  3641834.451  3661391.360      5      8      4    0.53%      85     11
#        9  3641834.451  3661306.513      5      7      5    0.53%     100     11
#       10  3641834.451  3661306.513      5      8      5    0.53%       6     11
#       20  3641834.451  3661306.513      5     18      7    0.53%       9     11
#       30  3641834.451  3660934.790      5     26      6    0.52%      35     11
#       40  3641834.451  3660934.790      5     33      9    0.52%       9     11
#       50  3641834.451  3660695.246      5     41      7    0.52%      79     12
#       60  3641834.451  3660695.246      5     51     10    0.52%      55     12
#       70  3641834.451  3660695.246      5     58     11    0.52%      73     12
#       80  3641834.451  3660355.817      5     68     12    0.51%      75     12
#       90  3641834.451  3660355.817      5     73     11    0.51%      26     12
#      100  3641834.451  3660355.817      5     81     14    0.51%      37     12
# Elapsed time (sec): 13, estimated tree completion: 0.07198
# Heap usage: 791MB (peak 791MB, 28MB system)
# B&B tree size: 2.5MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      200  3641834.451  3660327.825      5    148      8    0.51%      77     13
# q    274  3642327.261  3660327.825      6    165     29    0.49%       0     13
#      301  3642327.261  3660327.825      6    177     18    0.49%      58     14
#      401  3642327.261  3660327.825      6    209     20    0.49%       9     14
# q    460  3647194.854  3660327.825      7    231     14    0.36%       0     15
#      512  3647194.854  3660327.825      7    182      1    0.36%       2     15
#      615  3647194.854  3660283.175      7    193     38    0.36%      20     15
#      717  3647194.854  3660283.175      7    208     23    0.36%      84     15
#      818  3647194.854  3660283.175      7    204     16    0.36%      36     16
# *    900  3647391.874  3660283.175      8    181     47    0.35%       0     16
#      918  3647391.874  3660283.175      8    174     46    0.35%      39     16
# q    959  3649148.873  3660283.175      9    159     19    0.30%       0     16
#     1018  3649148.873  3660283.175      9    133     44    0.30%      24     16
#     1118  3649148.873  3659684.081      9    122     27    0.29%      39     17
#     1219  3649148.873  3659644.041      9     93     16    0.29%      32     17
#     1320  3649148.873  3659644.041      9     62     16    0.29%      33     17
# q   1339  3651010.894  3659644.041     10     57     16    0.24%       0     17
#     1420  3651010.894  3659644.041     10     44     13    0.24%      44     17
#     1522  3651010.894  3659644.041     10     22     26    0.24%      22     17
#     1622  3651010.894  3658836.499     10     11      1    0.21%       2     18
# Elapsed time (sec): 18, estimated tree completion: 0.99999
# Heap usage: 1556MB (peak 1598MB, 48MB system)
# B&B tree size: 0.8MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     1722  3651010.894  3657147.875     10      9     32    0.17%       1     18
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.651010893868164e+06
# Final MIP bound                       : 3.651014544879058e+06
#   Solution time / primaldual integral :     18.65s/  7.358756%
#   Number of solutions found / nodes   :        10 /      1737
#   Max primal violation      (abs/rel) : 1.826e-06 / 1.826e-06
#   Max integer violation     (abs    ) : 4.533e-11
# Scheduled Movies in Order:
#    Time Slot         Day Start Time End Time  Movie Index  \
# 0         34  2024-10-02      07:00    09:30           58
# 1         39  2024-10-02      09:30    12:30          192
# 2         45  2024-10-02      12:30    15:30           14
# 3         51  2024-10-02      15:30    18:00          358
# 4         56  2024-10-02      18:00    20:30          428
# 5         61  2024-10-02      20:30    07:00           53
#
#                                  Movie Title  num_slots  movie_budget  \
# 0  Harry Potter and the Order of the Phoenix          5     150000000
# 1                                 GoodFellas          6      25000000
# 2                   The Shawshank Redemption          6      25000000
# 3                                    Cruella          5     200000000
# 4                          Top Gun: Maverick          5     170000000
# 5                              The Godfather          7       6000000
#
#    box_office_revenue  n_ad_breaks
# 0           938212738            5
# 1            46835000            5
# 2            28341469            5
# 3           233503234            5
# 4          1488732821            5
# 5           245066411            6
# FICO Xpress v9.4.2, Hyper, solve started 13:24:16, Nov 24, 2024
# Heap usage: 29MB (peak 29MB, 9244KB system)
# Maximizing MILP Movie_Scheduling_Problem using up to 12 threads and up to 7528MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#      56524 rows        38198 cols       149026 elements     19906 entities
# Presolved problem has:
#      37694 rows        19906 cols       111904 elements     19906 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 42MB (peak 67MB, 9244KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 3.31e-02,  1.65e+05] / [ 1.56e-02,  1.97e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.36e+02] / [ 1.00e+00,  1.36e+02]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 3.31e-02,  1.65e+05]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 22, support set: 1184
#  Number of orbits: 370, largest orbit: 7
#  Row orbits: 700, row support: 2240
# Will try to keep branch and bound tree memory usage below 5.1GB
#  *** Solution found:  3072454.299   Time:   1.05    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (11 threads)
#
#               Concurrent-Solve,   1s
#             Dual                      Barrier
#     objective   sum inf
#  P  3566852.3   .0000000 |
#                          |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 251 simplex iterations, 0.04s
#         Barrier: 0 barrier and 0 simplex iterations, 0.05s
#             Barrier used 11 threads 6 cores
#             Barrier used AVX2 support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    251       3566852.327      P      0     0        .000000     1
# Dual solved problem
#   251 simplex iterations in 0.06 seconds at time 1
#
# Final objective                       : 3.566852327190520e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 2.070e-11 / 1.472e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a         3536343.727  3566852.327      2                  0.86%       0      1
# g         3557448.018  3566852.327      3                  0.26%       0      1
#
# Performing root presolve...
#
# Reduced problem has:    4783 rows    2491 columns     13928 elements
# Presolve dropped   :   32911 rows   17415 columns     97976 elements
# Presolve tightened :      1594 elements
# Symmetric problem: generators: 14, support set: 483
#  Number of orbits: 123, largest orbit: 7
#  Row orbits: 243, row support: 956
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 141 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#    256       191301366.1      D   1821     0        .000000     1
#    443       3566762.558      P      0     0        .000000     1
# Optimal solution found
# Dual solved problem
#   443 simplex iterations in 0.01 seconds at time 1
#
# Final objective                       : 3.566762558405767e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 1.826e-11 / 1.321e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3557448.018  3565180.193      3    360      0    0.22%      70      1
#    2  K   3557448.018  3564841.510      3    454    341    0.21%      68      1
#    3  K   3557448.018  3564768.364      3    105    432    0.21%      62      1
#
# Cuts in the matrix         : 146
# Cut elements in the matrix : 951
#
# Performing root presolve...
#
# Reduced problem has:    2649 rows    1319 columns      8267 elements
# Presolve dropped   :    2280 rows    1172 columns      6612 elements
# Presolve tightened :       411 elements
# Symmetric problem: generators: 9, support set: 300
#  Number of orbits: 54, largest orbit: 7
#  Row orbits: 104, row support: 578
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 66 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   1726       123158765.0      D   1058     0        .000000     1
#   1899       3566757.120      P      0     0        .000000     1
# Optimal solution found
# Dual solved problem
#   1899 simplex iterations in 0.00 seconds at time 1
#
# Final objective                       : 3.566757120156992e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 2.910e-11 / 1.606e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3557448.018  3564540.712      3    105    105    0.20%      67      2
#    2  K   3557448.018  3564509.769      3    240    103    0.20%      67      2
#    3  K   3557448.018  3563010.299      3     49    235    0.16%      13      2
#    4  K   3557448.018  3562068.969      3    173     45    0.13%      81      2
#
# Cuts in the matrix         : 223
# Cut elements in the matrix : 7543
#
# Performing root presolve...
#
# Reduced problem has:    1208 rows     552 columns      6730 elements
# Presolve dropped   :    1520 rows     767 columns      8114 elements
# Presolve tightened :       529 elements
# Symmetric problem: generators: 6, support set: 151
#  Number of orbits: 50, largest orbit: 5
#  Row orbits: 88, row support: 266
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 49 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   3203       55466944.52      D    464     0        .000000     2
#   3337       3566551.971      P      0     0        .000000     2
# Optimal solution found
# Dual solved problem
#   3337 simplex iterations in 0.00 seconds at time 2
#
# Final objective                       : 3.566551970954987e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 1.455e-11 / 1.102e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3557448.018  3561296.992      3    210    166    0.11%      54      2
#    2  K   3557448.018  3561219.912      3     86    201    0.11%      66      2
#    3  K   3557448.018  3561143.215      3    173     80    0.10%      70      2
#    4  K   3557448.018  3561130.447      3    283    175    0.10%      85      2
#    5  K   3557448.018  3561104.366      3    350    277    0.10%      94      2
#    6  K   3557448.018  3561058.808      3    351    341    0.10%      84      2
#    7  K   3557448.018  3561027.270      3    401    361    0.10%      88      2
#    8  K   3557448.018  3561008.445      3    151    525    0.10%      77      2
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 83
# Cut elements in the matrix : 994
#
# Starting tree search.
# Deterministic mode with up to 12 running threads and up to 32 tasks.
# Heap usage: 78MB (peak 149MB, 15MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3557448.018  3560900.142      3      2      1    0.10%      97      2
#        2  3557448.018  3560900.142      3      2      3    0.10%      34      2
#        3  3557448.018  3560900.142      3      3      3    0.10%      87      2
#        4  3557448.018  3560617.984      3      4      4    0.09%      44      2
#        5  3557448.018  3560617.984      3      5      4    0.09%      44      2
#        6  3557448.018  3560617.984      3      4      4    0.09%      35      2
#        7  3557448.018  3560617.984      3      3      3    0.09%      51      2
#        8  3557448.018  3560617.984      3      2      4    0.09%      63      2
#        9  3557448.018  3560617.984      3      3      4    0.09%      67      2
#       10  3557448.018  3560617.984      3      2      4    0.09%      66      2
#       21  3557448.018  3560336.833      3      2      7    0.08%      16      2
#       32  3557448.018  3560328.317      3      2      8    0.08%      30      2
#       42  3557448.018  3560153.445      3      3      8    0.08%      30      2
#       52  3557448.018  3559421.534      3      1     11    0.06%      50      2
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.557448017569857e+06
# Final MIP bound                       : 3.557451575017875e+06
#   Solution time / primaldual integral :      2.77s/ 47.313053%
#   Number of solutions found / nodes   :         3 /        61
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# Scheduled Movies in Order:
#    Time Slot         Day Start Time End Time  Movie Index  \
# 0         68  2024-10-03      07:00    09:00            5
# 1         72  2024-10-03      09:00    11:30          218
# 2         77  2024-10-03      11:30    13:30          205
# 3         81  2024-10-03      13:30    15:30          433
# 4         85  2024-10-03      15:30    18:30            2
# 5         91  2024-10-03      18:30    22:00          355
# 6         98  2024-10-03      22:00    07:00          368
#
#             Movie Title  num_slots  movie_budget  box_office_revenue  \
# 0              Deadpool          4      58000000           783100000
# 1  Fifty Shades of Grey          5      40000000           571006128
# 2         Me Before You          4      20000000           207945075
# 3    Fifty Shades Freed          4      55000000           368307760
# 4       The Dark Knight          6     185000000          1004558444
# 5            The Batman          7     185000000           770945583
# 6                   Saw          4       1200000           103911669
#
#    n_ad_breaks
# 0            4
# 1            5
# 2            4
# 3            4
# 4            6
# 5            6
# 6            4
# full df:     Time Slot         Day Start Time End Time  Movie Index  \
# 0           0  2024-10-01      07:00    09:30          539
# 1           5  2024-10-01      09:30    13:30           17
# 2          13  2024-10-01      13:30    16:30           10
# 3          19  2024-10-01      16:30    18:30           93
# 4          23  2024-10-01      18:30    22:00           22
# 5          30  2024-10-01      22:00    07:00          403
# 6          34  2024-10-02      07:00    09:30           58
# 7          39  2024-10-02      09:30    12:30          192
# 8          45  2024-10-02      12:30    15:30           14
# 9          51  2024-10-02      15:30    18:00          358
# 10         56  2024-10-02      18:00    20:30          428
# 11         61  2024-10-02      20:30    07:00           53
# 12         68  2024-10-03      07:00    09:00            5
# 13         72  2024-10-03      09:00    11:30          218
# 14         77  2024-10-03      11:30    13:30          205
# 15         81  2024-10-03      13:30    15:30          433
# 16         85  2024-10-03      15:30    18:30            2
# 17         91  2024-10-03      18:30    22:00          355
# 18         98  2024-10-03      22:00    07:00          368
#
#                                   Movie Title  num_slots  movie_budget  \
# 0                      Thor: Love and Thunder          5     250000000
# 1                                     Titanic          8     200000000
# 2                                Forrest Gump          6      55000000
# 3                                The Hangover          4      35000000
# 4                     The Wolf of Wall Street          7     100000000
# 5                                       After          4      14000000
# 6   Harry Potter and the Order of the Phoenix          5     150000000
# 7                                  GoodFellas          6      25000000
# 8                    The Shawshank Redemption          6      25000000
# 9                                     Cruella          5     200000000
# 10                          Top Gun: Maverick          5     170000000
# 11                              The Godfather          7       6000000
# 12                                   Deadpool          4      58000000
# 13                       Fifty Shades of Grey          5      40000000
# 14                              Me Before You          4      20000000
# 15                         Fifty Shades Freed          4      55000000
# 16                            The Dark Knight          6     185000000
# 17                                 The Batman          7     185000000
# 18                                        Saw          4       1200000
#
#     box_office_revenue  n_ad_breaks
# 0            760928081            4
# 1           2264162353            7
# 2            677387716            5
# 3            469310836            4
# 4            392000000            7
# 5             69497587            4
# 6            938212738            5
# 7             46835000            5
# 8             28341469            5
# 9            233503234            5
# 10          1488732821            5
# 11           245066411            6
# 12           783100000            4
# 13           571006128            5
# 14           207945075            4
# 15           368307760            4
# 16          1004558444            6
# 17           770945583            6
# 18           103911669            4

# %%
calculate_license_price(schedule_df= three_days)
# Out:
#                                         movie  license_fee  \
# 0                      Thor: Love and Thunder   1525113.70
# 1                                     Titanic   3208994.82
# 2                                Forrest Gump    956865.26
# 3                                The Hangover    659173.00
# 4                     The Wolf of Wall Street    722400.00
# 5                                       After    128997.10
# 6   Harry Potter and the Order of the Phoenix   1497855.29
# 7                                  GoodFellas    128202.00
# 8                    The Shawshank Redemption    106009.76
# 9                                     Cruella    772203.88
# 10                          Top Gun: Maverick   2206479.39
# 11                              The Godfather    320479.69
# 12                                   Deadpool   1090920.00
# 13                       Fifty Shades of Grey    793207.35
# 14                              Me Before You    309534.09
# 15                         Fifty Shades Freed    585969.31
# 16                            The Dark Knight   1661470.13
# 17                                 The Batman   1381134.70
# 18                                        Saw    139574.00
#
#     cost_per_ad_slot_cost  num_slots
# 0               381278.42          4
# 1               458427.83          7
# 2               191373.05          5
# 3               164793.25          4
# 4               103200.00          7
# 5                32249.28          4
# 6               299571.06          5
# 7                25640.40          5
# 8                21201.95          5
# 9               154440.78          5
# 10              441295.88          5
# 11               53413.28          6
# 12              272730.00          4
# 13              158641.47          5
# 14               77383.52          4
# 15              146492.33          4
# 16              276911.69          6
# 17              230189.12          6
# 18               34893.50          4

# %%
# # get specifically prime time ad slots 
# prime_time_df= pd.DataFrame(data = ch_A_schedule_30min.iloc[22:30,:])
# for k in range(84):
#     rest = ch_A_schedule_30min.iloc[22+(34*k):30+(34*k),:]
#     prime_time_df = pd.concat([prime_time_df,rest])
# #print(prime_time_df)

# %%
cha3 = ch_A_schedule_30min.head(103)
# cha3.drop(['children_baseline_view_count', 'adults_baseline_view_count','retirees_baseline_view_count'], axis=1, inplace=True)
cha3.head()
# Out:
#                  Date  children_baseline_view_count  \
# 0 2024-10-01 07:00:00                      0.019383
# 1 2024-10-01 07:30:00                      0.015485
# 2 2024-10-01 08:00:00                      0.009684
# 3 2024-10-01 08:30:00                      0.004744
# 4 2024-10-01 09:00:00                      0.001831
#
#    adults_baseline_view_count  retirees_baseline_view_count  prime_time_factor
# 0                    0.022296                      0.003611                1.0
# 1                    0.022928                      0.004694                1.0
# 2                    0.024245                      0.006021                1.0
# 3                    0.026238                      0.007612                1.0
# 4                    0.028892                      0.009478                1.0

# %%
def fill_ch_A(df_to_fill, df_of_movies):
    d = 0
    x = 0
    for i in df_of_movies['num_slots']:
        # val = df_of_movies['Movie Title'].iloc[d]
        df_to_fill.loc[x:x+i, 'movie'] = df_of_movies['Movie Title'].iloc[d]
        df_to_fill.loc[x:x+i, 'ad_cost'] = movie_money_info['cost_per_ad_slot_cost'].iloc[d]
        d += 1
        x += i
    # print(df_to_fill['movie'])
    return df_to_fill
    
fill_ch_A(df_to_fill = cha3, df_of_movies = three_days)
# Out:
#                    Date  children_baseline_view_count  \
# 0   2024-10-01 07:00:00                      0.019383
# 1   2024-10-01 07:30:00                      0.015485
# 2   2024-10-01 08:00:00                      0.009684
# 3   2024-10-01 08:30:00                      0.004744
# 4   2024-10-01 09:00:00                      0.001831
# ..                  ...                           ...
# 98  2024-10-03 22:00:00                      0.001094
# 99  2024-10-03 22:30:00                      0.000555
# 100 2024-10-03 23:00:00                      0.000264
# 101 2024-10-03 23:30:00                      0.000118
# 102 2024-10-04 07:00:00                      0.019383
#
#      adults_baseline_view_count  retirees_baseline_view_count  \
# 0                      0.022296                      0.003611
# 1                      0.022928                      0.004694
# 2                      0.024245                      0.006021
# 3                      0.026238                      0.007612
# 4                      0.028892                      0.009478
# ..                          ...                           ...
# 98                     0.101299                      0.012007
# 99                     0.095718                      0.009817
# 100                    0.089721                      0.007904
# 101                    0.083435                      0.006268
# 102                    0.022296                      0.003611
#
#      prime_time_factor                   movie    ad_cost
# 0             1.000000  Thor: Love and Thunder  381278.42
# 1             1.000000  Thor: Love and Thunder  381278.42
# 2             1.000000  Thor: Love and Thunder  381278.42
# 3             1.000000  Thor: Love and Thunder  381278.42
# 4             1.000000  Thor: Love and Thunder  381278.42
# ..                 ...                     ...        ...
# 98            1.083333                     Saw   34893.50
# 99            1.000000                     Saw   34893.50
# 100           1.000000                     Saw   34893.50
# 101           1.000000                     Saw   34893.50
# 102           1.000000                     Saw   34893.50
#
# [103 rows x 7 columns]

# %%
all_slots = pd.DataFrame()
# cost per ad slot on each channel
all_slots['0'] = ch_0_schedule_30min['ad_slot_price']
all_slots['1'] = ch_1_schedule_30min['ad_slot_price']
all_slots['2'] = ch_2_schedule_30min['ad_slot_price']

# basic stats
# all_slots['avg'] = round(all_slots.mean(axis = 1), 2)
all_slots['max'] = all_slots.max(axis=1)
all_slots['min'] = all_slots.min(axis=1)
all_slots['our price'] = round(cha3['ad_cost'],2)

# identify best and worst channel 
all_slots['max ch #'] = all_slots[['0','1','2']].idxmax(axis=1)
all_slots['min ch #'] = all_slots[['0','1','2']].idxmin(axis=1)

# potential profits/ upcharges
# find out percentage difference of most expensive ad compared to ours
all_slots['times_more_expensive'] = round(all_slots['our price']/all_slots['max'],2)
# all_slots['smallest_profit'] = all_slots['our_sell_price'] - all_slots['max']
# all_slots['greatest_profit'] = all_slots['our_sell_price'] - all_slots['min']
all_slots['cost_per_viewer'] = round(all_slots['our price'] / ((cha3['children_baseline_view_count']+cha3['adults_baseline_view_count']+cha3['retirees_baseline_view_count'])*1_000_000),2)


all_slots.head()
# Out:
#           0         1          2        max       min  our price max ch #  \
# 0  56995.17  25458.66  365283.35  365283.35  25458.66  381278.42        2
# 1  56995.17  25458.66  365283.35  365283.35  25458.66  381278.42        2
# 2  25479.06  16629.10  365283.35  365283.35  16629.10  381278.42        2
# 3  25479.06  16629.10  365283.35  365283.35  16629.10  381278.42        2
# 4  25479.06  16629.10   17700.00   25479.06  16629.10  381278.42        0
#
#   min ch #  times_more_expensive  cost_per_viewer
# 0        1                  1.04             8.42
# 1        1                  1.04             8.84
# 2        1                  1.04             9.54
# 3        1                  1.04             9.88
# 4        1                 14.96             9.48

# %%
cha3['ad_cost'].sum()/((cha3['children_baseline_view_count'].sum() + cha3['adults_baseline_view_count'].sum() + cha3['retirees_baseline_view_count'].sum())*1000000)
# Out:
# 1.6894083059535145

# %%
p = []
p_flat = []
for m in cha3['movie']:
    v = movies_copy.index[movies_copy['title'] == m].to_list()
    p.append(v)
for i in p:
    for it in i:
        p_flat.append(it)
    
    child_expected_viewcounts = cha3['children_baseline_view_count']*movies_copy.loc[it, 'children_scaled_popularity']
    adults_expected_viewcounts = cha3['adults_baseline_view_count']*movies_copy.loc[it, 'adults_scaled_popularity']
    retirees_expected_viewcounts = cha3['retirees_baseline_view_count']*movies_copy.loc[it, 'retirees_scaled_popularity']

cha3['child_expected_viewcounts'] = child_expected_viewcounts
cha3['adults_expected_viewcounts'] = adults_expected_viewcounts
cha3['retirees_expected_viewcounts'] = retirees_expected_viewcounts
cha3['total_expected_viewers'] = (cha3['child_expected_viewcounts']+cha3['adults_expected_viewcounts']+cha3['retirees_expected_viewcounts']*1000000)
# cha3['cost_per_viewer'] = cha3['ad_cost']/(cha3['child_expected_viewcounts']+cha3['adults_expected_viewcounts']+cha3['retirees_expected_viewcounts']*1000000)
cha3['cost_per_viewer'] = cha3['ad_cost']/cha3['total_expected_viewers']

# %%
cha3.iloc[29:35]
# Out:
#                   Date  children_baseline_view_count  \
# 29 2024-10-01 21:30:00                      0.002026
# 30 2024-10-01 22:00:00                      0.001094
# 31 2024-10-01 22:30:00                      0.000555
# 32 2024-10-01 23:00:00                      0.000264
# 33 2024-10-01 23:30:00                      0.000118
# 34 2024-10-02 07:00:00                      0.019383
#
#     adults_baseline_view_count  retirees_baseline_view_count  \
# 29                    0.106340                      0.014459
# 30                    0.101299                      0.012007
# 31                    0.095718                      0.009817
# 32                    0.089721                      0.007904
# 33                    0.083435                      0.006268
# 34                    0.022296                      0.003611
#
#     prime_time_factor                                      movie    ad_cost  \
# 29           1.500000                    The Wolf of Wall Street  103200.00
# 30           1.083333                                      After   32249.28
# 31           1.000000                                      After   32249.28
# 32           1.000000                                      After   32249.28
# 33           1.000000                                      After   32249.28
# 34           1.000000  Harry Potter and the Order of the Phoenix  299571.06
#
#     child_expected_viewcounts  adults_expected_viewcounts  \
# 29                   0.000810                    0.106340
# 30                   0.000437                    0.101299
# 31                   0.000222                    0.095718
# 32                   0.000106                    0.089721
# 33                   0.000047                    0.083435
# 34                   0.007753                    0.022296
#
#     retirees_expected_viewcounts  cost_per_viewer  total_expected_viewers
# 29                      0.011567         8.921563            11567.479593
# 30                      0.009605         3.357408             9605.409663
# 31                      0.007853         4.106394             7853.430559
# 32                      0.006323         5.100376             6322.921664
# 33                      0.005014         6.431711             5014.105994
# 34                      0.002889       103.695518             2888.948984
