# %%
# Import packages and read-in files

import numpy as np
import pandas as pd
import xpress as xp
from datetime import datetime, timedelta
import os
import math 

# Read in files using the explicitly defined base path
ch_0_conversion_rates = pd.read_csv('channel_0_conversion_rates.csv')
ch_0_schedule = pd.read_csv('channel_0_schedule.csv')
ch_1_conversion_rates = pd.read_csv('channel_1_conversion_rates.csv')
ch_1_schedule = pd.read_csv('channel_1_schedule.csv')
ch_2_conversion_rates = pd.read_csv('channel_2_conversion_rates.csv')
ch_2_schedule = pd.read_csv('channel_2_schedule.csv')
ch_A_schedule = pd.read_csv('channel_A_schedule.csv')
movies_df = pd.read_csv('movie_database.csv')

# %%
# To use right xpress and get rid of unnecessary error codes
xp.init('C:/xpressmp/bin/xpauth.xpr')
pd.options.mode.copy_on_write = True

# %%
# FORMATING
# Convert 'Date-Time' columns to datetime format
date_cols = ['Date']

for df in [ch_0_conversion_rates, ch_0_schedule, ch_1_conversion_rates, ch_1_schedule,
           ch_2_conversion_rates, ch_2_schedule, ch_A_schedule]:
    df['Date'] = pd.to_datetime(df['Unnamed: 0'])
    df.set_index('Date', inplace=True)
    df.drop('Unnamed: 0', axis=1, inplace = True)
   

# Convert 'Release Date' in movie_database to datetime
movies_df['release_date'] = pd.to_datetime(movies_df['release_date'])

# Fill missing values if necessary
movies_df.fillna(0, inplace=True)

# %%
# Slot duration 30 minutes
slot_duration = 30  # minutes
movies_df['slots_needed'] = (movies_df['runtime_with_ads'] / slot_duration).apply(lambda x: int(x)).astype(int)

# %%
from datetime import datetime, timedelta

num_days = 6

# Define the broadcasting start and end dates
broadcast_start_date = datetime.strptime("2024-10-01", "%Y-%m-%d")
broadcast_end_date = broadcast_start_date + timedelta(days=num_days)  # 7 days including start date

# Define daily broadcast start and end times
daily_broadcast_start_time = timedelta(hours=7, minutes=0)
daily_broadcast_end_time = timedelta(hours=23, minutes=30)

# Generate all time slots over the date range
time_slots = []
current_date = broadcast_start_date
while current_date <= broadcast_end_date:
    # Set the start and end times for the current day
    day_start = datetime.combine(current_date.date(), datetime.min.time()) + daily_broadcast_start_time
    day_end = datetime.combine(current_date.date(), datetime.min.time()) + daily_broadcast_end_time
    
    current_time = day_start
    while current_time <= day_end:
        time_slots.append(current_time)
        current_time += timedelta(minutes=slot_duration)
    
    # Move to the next day
    current_date += timedelta(days=1)

# Create mappings between time slots and indices
time_to_index = {t: idx for idx, t in enumerate(time_slots)}
index_to_time = {idx: t for idx, t in enumerate(time_slots)}

# %%
# Print the first few time slots
print("First 10 Time Slots:")
for ts in time_slots[:10]:
    print(ts.strftime('%Y-%m-%d %H:%M'))

# Print the last few time slots
print("\nLast 10 Time Slots:")
for ts in time_slots[-10:]:
    print(ts.strftime('%Y-%m-%d %H:%M'))
# Out:
# First 10 Time Slots:
# 2024-10-01 07:00
# 2024-10-01 07:30
# 2024-10-01 08:00
# 2024-10-01 08:30
# 2024-10-01 09:00
# 2024-10-01 09:30
# 2024-10-01 10:00
# 2024-10-01 10:30
# 2024-10-01 11:00
# 2024-10-01 11:30
#
# Last 10 Time Slots:
# 2024-10-07 19:00
# 2024-10-07 19:30
# 2024-10-07 20:00
# 2024-10-07 20:30
# 2024-10-07 21:00
# 2024-10-07 21:30
# 2024-10-07 22:00
# 2024-10-07 22:30
# 2024-10-07 23:00
# 2024-10-07 23:30

# %%
from datetime import time
# Set 'Date' as index
# ch_A_schedule.set_index('Date', inplace=True)

# Resample to 30-minute intervals (use mean of groups)
ch_A_schedule_30min = ch_A_schedule.resample('30T').mean().reset_index()

# Define start and end times for filtering
daily_start_time = time(7, 0)  # 7:00 AM
daily_end_time = time(23, 55)  # 11:55 PM

# Filter rows to include only time slots within the desired range 
ch_A_schedule_30min['time'] = ch_A_schedule_30min['Date'].dt.time
ch_A_schedule_30min = ch_A_schedule_30min[
    (ch_A_schedule_30min['time'] >= daily_start_time) &
    (ch_A_schedule_30min['time'] <= daily_end_time)
].drop(columns=['time'])

# Print the first 5 rows
print("First 5 rows of ch_A_schedule_30min:")
print(ch_A_schedule_30min.head(3))
# Out:
# First 5 rows of ch_A_schedule_30min:
#                  Date  children_baseline_view_count  \
# 0 2024-10-01 07:00:00                      0.019383
# 1 2024-10-01 07:30:00                      0.015485
# 2 2024-10-01 08:00:00                      0.009684
#
#    adults_baseline_view_count  retirees_baseline_view_count  prime_time_factor
# 0                    0.022296                      0.003611                1.0
# 1                    0.022928                      0.004694                1.0
# 2                    0.024245                      0.006021                1.0
# C:\Users\Elie\AppData\Local\Temp\ipykernel_1516\4019587516.py:6: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   ch_A_schedule_30min = ch_A_schedule.resample('30T').mean().reset_index()

# %%
# # Map baseline viewership to time slot indices
# baseline_viewership = {}
# for idx, row in ch_A_schedule_30min.iterrows():
#     time_slot_datetime = row['Date']
#     # Find the corresponding time slot index
#     time_slot_index = time_to_index.get(time_slot_datetime, None)
#     if time_slot_index is not None:
#         baseline_viewership[time_slot_index] = {
#             'children': row['children_baseline_view_count'],
#             'adults': row['adults_baseline_view_count'],
#             'retirees': row['retirees_baseline_view_count'],
#             'prime_time_factor': row.get('prime_time_factor', 1)
#         }

# # Print the first 5 rows
# print("Print timeslot_index 1 of dictionary baseline_viewership:")
# print(baseline_viewership[1])

# %%
# Check for duplicate movie titles
duplicate_titles = movies_df[movies_df.duplicated(subset=['title'], keep=False)]
if not duplicate_titles.empty:
    print("Duplicate movie titles found:")
    print(duplicate_titles['title'])
else:
    print("No duplicate movie titles found.")
# Out:
# Duplicate movie titles found:
# 4                 The Avengers
# 17                     Titanic
# 76               The Lion King
# 105       Beauty and the Beast
# 149        Alice in Wonderland
#                  ...
# 5748              Midnight Sun
# 5761                The Island
# 5773            The Shaggy Dog
# 5855    Fun with Dick and Jane
# 5879        The Perfect Weapon
# Name: title, Length: 258, dtype: object

# %%
# Small movies DF to practice with code

movies_small = movies_df.head(100)

# %%
def get_views(m, t_idx, movies, our_channel):
    # Baseline viewership at time slot t_idx
    baseline = {
        'children': our_channel.iloc[t_idx]['children_baseline_view_count'],
        'adults': our_channel.iloc[t_idx]['adults_baseline_view_count'],
        'retirees': our_channel.iloc[t_idx]['retirees_baseline_view_count']
    }
    
    # Scaled popularity of movie m
    popularity = {
        'children': movies.loc[m, 'children_scaled_popularity'],
        'adults': movies.loc[m, 'adults_scaled_popularity'],
        'retirees': movies.loc[m, 'retirees_scaled_popularity']
    }
    
    # Calculate expected viewership (assuming total population of 1,000,000)
    total_population = 1_000_000
    viewership = sum(
        baseline[demo] * popularity[demo] * total_population
        for demo in ['children', 'adults', 'retirees']
    )
    
    return viewership

# %%
def model(T, movies, our_channel):
    prob = xp.problem(name="Movie_Scheduling_Problem")
    
    # Constants
    slots_per_day = 34  # Number of slots per day (e.g., from 07:00 to 23:30)
    days = len(time_slots) // slots_per_day  # Number of days in the schedule
    M = len(time_slots)  # Big M for constraints
    T_end = len(time_slots) - 1  # Last time slot index

    
    # Decision Variables
    x = {(m, t): xp.var(vartype=xp.binary, name='x_{0}_{1}'.format(m, t)) 
         for m in movies.index for t in T}
    prob.addVariable(list(x.values()))
    
    y = {m: xp.var(vartype=xp.binary, name='y_{0}'.format(m)) for m in movies.index}
    prob.addVariable(list(y.values()))
 
    
    s = {m: xp.var(vartype=xp.integer, name='s_{0}'.format(m)) for m in movies.index}
    e = {m: xp.var(vartype=xp.integer, name='e_{0}'.format(m)) for m in movies.index}
    prob.addVariable(list(s.values()))
    prob.addVariable(list(e.values()))
    
    u = {(m, t): xp.var(vartype=xp.continuous, name='u_{0}_{1}'.format(m, t)) 
         for m in movies.index for t in T}
    prob.addVariable(list(u.values()))
    
    decision_vars = [x, y, s, e]

    # Constraints
    
    # 1. Movie Duration Constraint
    for m in movies.index:
        prob.addConstraint(
            xp.Sum(x[m, t] for t in T) == movies.loc[m, 'slots_needed'] * y[m]
        )
    
    # 2. Time Slot Occupancy Constraint
    for t in T:
        prob.addConstraint(
            xp.Sum(x[m, t] for m in movies.index) == 1
        )
    
    # 3. Start Time Constraints
    for m in movies.index:
        for t in T:
            prob.addConstraint(
                s[m] <= t * x[m, t] + (1 - x[m, t]) * M
            )
    
    # 4. End Time Constraints
    for m in movies.index:
        for t in T:
            prob.addConstraint(
                e[m] >= (t + 1) * x[m, t]
            )
    
    # 5. Movie Duration Relationship Constraint
    for m in movies.index:
        prob.addConstraint(
            e[m] - s[m] == movies.loc[m, 'slots_needed'] * y[m]
        )
    
    prob.addConstraint(s[m] + movies.loc[m, 'slots_needed'] -1 <= T_end for m in movies.index)

    # 7. View Count Constraints
    for m in movies.index:
        for t_idx, t in enumerate(T):
            expected_viewership = get_views(m, t_idx, movies, our_channel)
            prob.addConstraint(
                u[m, t] == expected_viewership * x[m, t]
            )
    
    # 9. Objective Function
    prob.setObjective(
        xp.Sum(u[m, t] for m in movies.index for t in T),
        sense=xp.maximize
    )
    
    return prob, decision_vars

# %%
# Making schedule layout
def get_time(slot_index):
    return time_slots[slot_index].time()

used_movie_ids = []
def get_sched(prob, movies, decision_vars): 
    
    x = decision_vars[0]
    y = decision_vars[1]
    s = decision_vars[2]
    e = decision_vars[3]
    
    scheduled_movies = []
    used_movie_ids = []


    for m_idx, m_row in movies.iterrows():
        y_value = prob.getSolution(y[m_idx])
        if y_value > 0.5:  # Movie is scheduled
            used_movie_ids.append(m_idx)
            start_slot = int(prob.getSolution(s[m_idx]))
            end_slot = int(prob.getSolution(e[m_idx]))
    
            # Ensure the end slot is valid
            if end_slot < len(time_slots):
                # Get the corresponding day and times
                start_time = time_slots[start_slot]
                end_time = time_slots[end_slot]
                day = start_time.strftime('%Y-%m-%d')
                start_time_formatted = start_time.strftime('%H:%M')
                end_time_formatted = end_time.strftime('%H:%M')
    
                # Append the movie schedule
                scheduled_movies.append({
                    'Time Slot': start_slot,
                    'Day': day,
                    'Start Time': start_time_formatted,
                    'End Time': end_time_formatted,
                    'Movie Index': m_idx,
                    'Movie Title': m_row['title']
                })

    # Convert to a DataFrame for better organization
    schedule_df = pd.DataFrame.from_dict(scheduled_movies)
    
    # Sort by day and time slot
    schedule_df.sort_values(by=['Day', 'Time Slot'], inplace=True)
    
    # Reset index for cleaner output
    schedule_df.reset_index(drop=True, inplace=True)
    
    # Print the schedule
    print("Scheduled Movies in Order:")
    print(schedule_df)

    return scheduled_movies, used_movie_ids

# %%
# Putting it all together

def movie_sched(number_days, movies, our_channel):
    used_movie_ids= []
    total_schedule = []
    for k in range(number_days):

        T = range(k*34, (k*34)+33)

        prob, decision_vars =  model(T, movies, our_channel)

        prob.solve()
        
        scheduled_movies, used_movie_ids = get_sched(prob,movies,decision_vars)
        
        for i in used_movie_ids:
            movies.drop(i, inplace = True)
        total_schedule.append(scheduled_movies)
        
    return scheduled_movies

# %%
movie_sched(number_days=2, movies=movies_small, our_channel=ch_A_schedule_30min)
# Out:
# FICO Xpress v9.4.2, Hyper, solve started 20:09:26, Nov 21, 2024
# Heap usage: 4710KB (peak 4710KB, 4128KB system)
# Maximizing MILP Movie_Scheduling_Problem using up to 12 threads and up to 7528MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#       9111 rows         6141 cols        23941 elements      3204 entities
# Presolved problem has:
#       5994 rows         3112 cols        17617 elements      3112 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 6926KB (peak 10MB, 4128KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.61e+05] / [ 7.81e-03,  1.94e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.38e+02] / [ 1.00e+00,  2.38e+02]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 1.46e+04,  1.82e+05]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 9, support set: 420
#  Number of orbits: 105, largest orbit: 6
#  Row orbits: 201, row support: 804
# Will try to keep branch and bound tree memory usage below 5.1GB
#  *** Solution found:  3110307.004   Time:   0.09    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (11 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#     objective   sum inf
#  P  3362993.3   .0000000 |
#                          |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 292 simplex iterations, 0.01s
#         Barrier: 0 barrier and 0 simplex iterations, 0.01s
#             Barrier used 11 threads 6 cores
#             Barrier used AVX2 support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    292       3362993.334      P      0     0        .000000     0
# Dual solved problem
#   292 simplex iterations in 0.01 seconds at time 0
#
# Final objective                       : 3.362993333722618e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# P         3118306.180  3362993.334      2                  7.28%       0      0
# P         3139172.412  3362993.334      3                  6.66%       0      0
# R         3196545.357  3362993.334      4                  4.95%       0      0
#    1  K   3196545.357  3362993.334      4    413      0    4.95%      77      0
#    2  K   3196545.357  3362993.334      4    198    368    4.95%      52      0
#    3  K   3196545.357  3362993.334      4    328    195    4.95%      74      0
#    4  K   3196545.357  3362356.836      4    404    314    4.93%      90      0
# a         3328774.568  3361524.623      5                  0.97%       0      0
#    5  K   3328774.568  3361524.623      5    394    409    0.97%      92      0
#    6  K   3328774.568  3360916.325      5    371    394    0.96%      79      0
#    7  K   3328774.568  3360577.717      5    513    353    0.95%     102      0
# b         3343966.555  3359729.070      6                  0.47%       0      0
#    8  K   3343966.555  3359729.070      6    564    502    0.47%     121      0
#
# Cuts in the matrix         : 650
# Cut elements in the matrix : 4686
#
# Performing root presolve...
#
# Reduced problem has:    3907 rows    1717 columns     14056 elements
# Presolve dropped   :    2737 rows    1395 columns      8247 elements
# Presolve tightened :       845 elements
# Symmetric problem: generators: 7, support set: 306
#  Number of orbits: 68, largest orbit: 5
#  Row orbits: 130, row support: 585
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 78 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   2427       3362993.334      P      0     0        .000000     0
# Optimal solution found
# Dual solved problem
#   2427 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 3.362993333722616e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 3.008e-12 / 2.005e-12
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3343966.555  3358844.904      6    320    559    0.44%     108      0
#    2  K   3343966.555  3358479.817      6    448    309    0.43%     127      0
# P         3347152.136  3358479.817      7                  0.34%       0      1
# P         3348163.620  3358479.817      8                  0.31%       0      1
#    3  K   3348163.620  3358315.337      8    534    459    0.30%      82      1
#    4  K   3348163.620  3358161.210      8    689    536    0.30%      81      1
#    5  K   3348163.620  3358052.404      8    431    695    0.29%      60      1
#    6  K   3348163.620  3357675.870      8    862    428    0.28%      98      1
#
# Cuts in the matrix         : 945
# Cut elements in the matrix : 7475
#
# Performing root presolve...
#
# Reduced problem has:    2932 rows     988 columns     12548 elements
# Presolve dropped   :    1273 rows     729 columns      4519 elements
# Presolve tightened :       691 elements
# Symmetric problem: generators: 7, support set: 279
#  Number of orbits: 62, largest orbit: 5
#  Row orbits: 126, row support: 567
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 47 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   4959       95049906.41      D    913     0        .000000     1
#   5121       3362993.334      P      0     0        .000000     1
# Optimal solution found
# Dual solved problem
#   5121 simplex iterations in 0.00 seconds at time 1
#
# Final objective                       : 3.362993333722616e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 5.525e-11 / 3.683e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a         3356746.437  3357289.188      9                  0.02%       0      1
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.356746437173898e+06
# Final MIP bound                       : 3.356749793920335e+06
#   Solution time / primaldual integral :      1.37s/ 14.249364%
#   Number of solutions found / nodes   :         9 /         1
#   Max primal violation      (abs/rel) : 1.137e-13 / 5.030e-16
#   Max integer violation     (abs    ) : 4.441e-16
# Scheduled Movies in Order:
#    Time Slot         Day Start Time End Time  Movie Index  \
# 0          0  2024-10-01      07:00    10:00           11
# 1          6  2024-10-01      10:00    13:00           25
# 2         12  2024-10-01      13:00    16:30           91
# 3         19  2024-10-01      16:30    20:30           20
# 4         27  2024-10-01      20:30    23:30           46
#
#                                      Movie Title
# 0       Harry Potter and the Philosopher's Stone
# 1                          The Dark Knight Rises
# 2                                 The Green Mile
# 3  The Lord of the Rings: The Return of the King
# 4            Harry Potter and the Goblet of Fire
# FICO Xpress v9.4.2, Hyper, solve started 20:09:28, Nov 21, 2024
# Heap usage: 4625KB (peak 4625KB, 4134KB system)
# Maximizing MILP Movie_Scheduling_Problem using up to 12 threads and up to 7528MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#       8601 rows         5796 cols        22596 elements      3024 entities
# Presolved problem has:
#       5744 rows         2937 cols        16797 elements      2937 entities
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 6727KB (peak 10MB, 4134KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.61e+05] / [ 7.81e-03,  1.97e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.38e+02] / [ 1.00e+00,  2.38e+02]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 1.46e+04,  1.82e+05]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 7, support set: 350
#  Number of orbits: 105, largest orbit: 4
#  Row orbits: 204, row support: 680
# Will try to keep branch and bound tree memory usage below 5.1GB
# Starting concurrent solve with dual (1 thread) and barrier (11 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#     objective   sum inf
#  P  3326155.4   .0000000 |
#                          |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#            Dual: 234 simplex iterations, 0.01s
#         Barrier: 0 barrier and 0 simplex iterations, 0.01s
#             Barrier used 11 threads 6 cores
#             Barrier used AVX2 support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    234       3326155.423      P      0     0        .000000     0
# Dual solved problem
#   234 simplex iterations in 0.01 seconds at time 0
#
# Final objective                       : 3.326155422983564e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 1.698e-10 / 1.132e-10
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# g         3215833.254  3326155.423      1                  3.32%       0      0
# g         3253482.472  3325141.070      2                  2.16%       0      0
#    1  K   3253482.472  3325141.070      2    813      0    2.16%      95      0
#    2  K   3253482.472  3324783.779      2    284    759    2.14%      85      0
#    3  K   3253482.472  3324697.319      2    688    287    2.14%      91      0
#    4  K   3253482.472  3324363.183      2    455    680    2.13%      97      0
#    5  K   3253482.472  3323417.189      2    425    449    2.10%     102      0
#    6  K   3253482.472  3322855.723      2    797    422    2.09%      86      0
#    7  K   3253482.472  3322714.481      2    879    796    2.08%      95      0
#    8  K   3253482.472  3322346.861      2    690    866    2.07%     100      0
#    9  K   3253482.472  3322327.215      2    733    687    2.07%      87      0
# R         3274743.434  3322290.769      3                  1.43%       0      0
#   10  K   3274743.434  3322290.769      3    975    732    1.43%      90      0
#   11  K   3274743.434  3322174.162      3   1006    968    1.43%     108      0
#   12  K   3274743.434  3322085.753      3   1442   1009    1.43%     101      0
#   13  K   3274743.434  3321871.341      3   1512   1438    1.42%     129      0
#   14  K   3274743.434  3321524.857      3   1648   1510    1.41%     106      1
#   15  K   3274743.434  3321455.131      3   1327   1633    1.41%     130      1
#   16  K   3274743.434  3321432.825      3   1705   1327    1.41%     119      1
#   17  K   3274743.434  3321320.497      3     15   1709    1.40%       1      1
#   18  K   3274743.434  3321189.739      3   1776     32    1.40%     127      1
#   19  K   3274743.434  3321097.163      3    712   1757    1.40%      66      1
#   20  K   3274743.434  3320950.853      3   1812    719    1.39%     112      1
#   21  K   3274743.434  3320847.425      3   1860   1806    1.39%     128      1
#   22  K   3274743.434  3320767.061      3   1899   1855    1.39%     127      1
#   23  K   3274743.434  3320761.622      3    495   1906    1.39%      61      1
#   24  K   3274743.434  3320581.560      3   1905    495    1.38%     123      1
#   25  K   3274743.434  3320506.841      3   1227   1892    1.38%     125      1
#   26  K   3274743.434  3320333.512      3   1775   1223    1.37%     124      2
#   27  K   3274743.434  3320249.918      3   1886   1770    1.37%     128      2
#   28  K   3274743.434  3320211.541      3   1745   1893    1.37%      51      2
#   29  K   3274743.434  3320146.452      3   1911   1743    1.37%     119      2
#   30  K   3274743.434  3320057.360      3   1869   1900    1.36%     134      2
#   31  K   3274743.434  3320014.734      3   1815   1873    1.36%     109      2
#   32  K   3274743.434  3319940.651      3   1053   1821    1.36%      34      2
#   33  K   3274743.434  3319815.005      3   2012   1056    1.36%     142      2
#   34  K   3274743.434  3319752.319      3   2034   2000    1.36%     160      2
#   35  K   3274743.434  3319718.186      3   1052   3093    1.35%      76      3
# g         3292321.247  3319555.091      4                  0.82%       0      3
#   36  G   3292321.247  3319555.091      4   1910      8    0.82%     125      3
#   37  G   3292321.247  3319517.885      4   1513   3115    0.82%     137      3
# Heuristic search 'R' started
# R         3315902.630  3319517.885      5                  0.11%       0      3
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 426
# Cut elements in the matrix : 4427
#
# Performing root presolve...
#
# Reduced problem has:     752 rows     197 columns      3377 elements
# Presolve dropped   :    5418 rows    2740 columns     17847 elements
# Presolve tightened :       545 elements
# Symmetric problem: generators: 6, support set: 108
#  Number of orbits: 27, largest orbit: 4
#  Row orbits: 47, row support: 188
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 17 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#   9202       22030389.82      D    173     0        .000000     4
#   9312       3326155.423      P      0     0        .000000     4
# Optimal solution found
# Dual solved problem
#   9312 simplex iterations in 0.00 seconds at time 4
#
# Final objective                       : 3.326155422983564e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 7.716e-28 / 7.371e-28
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3315902.630  3317783.239      5    306     87    0.06%      67      4
#    2  K   3315902.630  3317270.724      5    304    820    0.04%     111      4
#
# Cuts in the matrix         : 96
# Cut elements in the matrix : 531
#
# Performing root presolve...
#
# Reduced problem has:     331 rows     116 columns      1105 elements
# Presolve dropped   :     124 rows      81 columns       430 elements
# Presolve tightened :        42 elements
# Symmetric problem: generators: 2, support set: 69
#  Number of orbits: 23, largest orbit: 3
#  Row orbits: 42, row support: 126
# Will try to keep branch and bound tree memory usage below 5.1GB
# Crash basis containing 8 structural columns created
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#  10685       12108185.58      D    108     0        .000000     4
#  10791       3326155.423      P      0     0        .000000     4
# Optimal solution found
# Dual solved problem
#   10791 simplex iterations in 0.00 seconds at time 4
#
# Final objective                       : 3.326155422983565e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 5.644e-11 / 5.473e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   3315902.630  3316893.240      5    259     13    0.03%      53      4
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 3.315902630205115e+06
# Final MIP bound                       : 3.315905946107746e+06
#   Solution time / primaldual integral :      4.52s/  4.155322%
#   Number of solutions found / nodes   :         5 /         1
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# Scheduled Movies in Order:
#    Time Slot         Day Start Time End Time  Movie Index  \
# 0         34  2024-10-02      07:00    09:30           82
# 1         39  2024-10-02      09:30    11:30           92
# 2         43  2024-10-02      11:30    14:30            9
# 3         49  2024-10-02      14:30    17:30           59
# 4         55  2024-10-02      17:30    20:30           65
# 5         61  2024-10-02      20:30    23:30           38
#
#                                     Movie Title
# 0                        The Amazing Spider-Man
# 1                               The Maze Runner
# 2                                  Pulp Fiction
# 3        Harry Potter and the Half-Blood Prince
# 4  Harry Potter and the Deathly Hallows: Part 1
# 5      Harry Potter and the Prisoner of Azkaban
# [{'Time Slot': 43,
#   'Day': '2024-10-02',
#   'Start Time': '11:30',
#   'End Time': '14:30',
#   'Movie Index': 9,
#   'Movie Title': 'Pulp Fiction'},
#  {'Time Slot': 61,
#   'Day': '2024-10-02',
#   'Start Time': '20:30',
#   'End Time': '23:30',
#   'Movie Index': 38,
#   'Movie Title': 'Harry Potter and the Prisoner of Azkaban'},
#  {'Time Slot': 49,
#   'Day': '2024-10-02',
#   'Start Time': '14:30',
#   'End Time': '17:30',
#   'Movie Index': 59,
#   'Movie Title': 'Harry Potter and the Half-Blood Prince'},
#  {'Time Slot': 55,
#   'Day': '2024-10-02',
#   'Start Time': '17:30',
#   'End Time': '20:30',
#   'Movie Index': 65,
#   'Movie Title': 'Harry Potter and the Deathly Hallows: Part 1'},
#  {'Time Slot': 34,
#   'Day': '2024-10-02',
#   'Start Time': '07:00',
#   'End Time': '09:30',
#   'Movie Index': 82,
#   'Movie Title': 'The Amazing Spider-Man'},
#  {'Time Slot': 39,
#   'Day': '2024-10-02',
#   'Start Time': '09:30',
#   'End Time': '11:30',
#   'Movie Index': 92,
#   'Movie Title': 'The Maze Runner'}]
